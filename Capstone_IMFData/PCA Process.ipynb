# %% [markdown]
# Principal Component Analysis Process:
#
# Following cell imports target values, creates initial chart definitions, created first exploratory unsupervised machine learning definitions, and stores some ISO country value mappings needed for choropleth charts in future cells:

# %%
import pandas as pd
import numpy as np

import random

import time
start_time = time.perf_counter()

from datetime import date

from sklearn.model_selection import KFold

from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_squared_error
import math

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.preprocessing import StandardScaler

from sklearn.inspection import permutation_importance

from sklearn.neighbors import NeighborhoodComponentsAnalysis
from sklearn.decomposition import PCA

from sklearn import preprocessing

from sklearn.neighbors import KNeighborsRegressor
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

import altair as alt

import altair as alt
from vega_datasets import data

world = alt.topo_feature(data.world_110m.url, feature='countries')

import warnings
# SettingWithCopyWarning: 
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead#
# warnings.filterwarnings("ignore", message="A value is trying to be set on a copy of a slice from a DataFrame.")
warnings.filterwarnings("ignore", message='''A value is trying to be set on a copy of a slice from a DataFrame.
Try using .loc[row_indexer,col_indexer] = value instead''')

#https://data.imf.org/?sk=388dfa60-1d26-4ade-b505-a05a558d9a42&sId=1479329132316

course_file_path = '/Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/'

imf_target_values_import = pd.read_csv('/Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/imf_gdp_pc_target_values.csv')

file_model_df = imf_target_values_import.copy()

file_model_df = file_model_df#.iloc[1:,:]
file_model_df['Country Name'] = file_model_df['GDP per capita, current prices\n (U.S. dollars per capita)']
file_model_df.index = file_model_df['Country Name']
file_model_df=file_model_df.drop(columns = ['Country Name','GDP per capita, current prices\n (U.S. dollars per capita)'])
file_model_df.set_axis([int(float(x)) for x in file_model_df.columns],axis = 'columns', inplace=True)

country_exclusion_list = [
'Africa (Region)',
'Asia and Pacific',
'Australia and New Zealand',
'Caribbean',
'Central America',
'Central Asia and the Caucasus',
'East Asia',
'Eastern Europe ', 
'Europe',
'Middle East (Region)',
'North Africa',
'North America',
'Pacific Islands ', 
'South America',
'South Asia',
'Southeast Asia',
'Sub-Saharan Africa (Region) ',
'Western Europe',
'Western Hemisphere (Region)',
'ASEAN-5',
'Advanced economies',
'Emerging and Developing Asia',
'Emerging and Developing Europe',
'Emerging market and developing economies',
'Euro area',
'European Union',
'Latin America and the Caribbean',
'Major advanced economies (G7)',
'Middle East and Central Asia',
'Other advanced economies',
'Sub-Saharan Africa',
'World',
'nan',
'NaN',
'©IMF, 2022'
]

model_df = file_model_df.copy()
model_df = model_df[~model_df.index.isin(country_exclusion_list)]
model_df=model_df.fillna(0).replace('no data',0)
model_df = model_df.loc[model_df.index.notna()]

completed_file_dfs = [
    
        'BOPAGG_02-04-2023 07-59-39-92_timeSeries/BOPAGG_02-04-2023 07-59-39-92_timeSeries.csv'#3
         ,'CDIS_01-15-2023 18-58-45-21_timeSeries/CDIS_01-15-2023 18-58-45-21_timeSeries.csv'
#          ,'CPI_02-07-2023 16-19-35-85_timeSeries/CPI_02-07-2023 16-19-35-85_timeSeries.csv'#6 #too big for github
         ,'ED_02-07-2023 04-41-04-68_timeSeries/ED_02-07-2023 04-41-04-68_timeSeries.csv'
         ,'EQ_02-04-2023 18-05-06-26_timeSeries/EQ_02-04-2023 18-05-06-26_timeSeries.csv'#9
         ,'FAS_02-04-2023 13-20-29-76_timeSeries/FAS_02-04-2023 13-20-29-76_timeSeries.csv'#10
         ,'FDI_07-14-2022 10-45-25-27_timeSeries/FDI_07-14-2022 10-45-25-27_timeSeries.csv'
         ,'FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries/FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries.csv'
         ,'FM_02-07-2023 04-43-40-20_timeSeries/FM_02-07-2023 04-43-40-20_timeSeries.csv'
         ,'FSI_02-03-2023 08-19-04-78_timeSeries/FSI_02-03-2023 08-19-04-78_timeSeries.csv'#14
         ,'FSIRE_02-04-2023 08-23-40-70_timeSeries/FSIRE_02-04-2023 08-23-40-70_timeSeries.csv'
         ,'GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries/GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries.csv'#16
#          ,'GFSCOFOG_02-07-2023 04-44-34-74_timeSeries/GFSCOFOG_02-07-2023 04-44-34-74_timeSeries.csv' #too big for github
#          ,'GFSE_02-07-2023 04-44-54-86_timeSeries/GFSE_02-07-2023 04-44-54-86_timeSeries.csv'#18#too big for github
#          ,'GFSFALCS_02-07-2023 04-45-22-02_timeSeries/GFSFALCS_02-07-2023 04-45-22-02_timeSeries.csv'#too big for github
#          ,'GFSIBS_02-06-2023 14-42-18-39_timeSeries/GFSIBS_02-06-2023 14-42-18-39_timeSeries.csv'#too big for github
#          ,'GFSMAB_02-07-2023 04-46-16-64_timeSeries/GFSMAB_02-07-2023 04-46-16-64_timeSeries.csv'#too big for github
#          ,'GFSR_02-07-2023 04-46-55-75_timeSeries/GFSR_02-07-2023 04-46-55-75_timeSeries.csv'#too big for github
#          ,'GFSSSUC_02-07-2023 04-47-28-17_timeSeries/GFSSSUC_02-07-2023 04-47-28-17_timeSeries.csv'#too big for github
        ,'HPDD_04-11-2020 23-37-06-60_timeSeries/HPDD_04-11-2020 23-37-06-60_timeSeries.csv'
#          ,'IFS_02-07-2023 12-51-31-57_timeSeries/IFS_02-07-2023 12-51-31-57_timeSeries.csv'#25#too big for github
#          ,'IRFCL_02-07-2023 08-35-05-78_timeSeries/IRFCL_02-07-2023 08-35-05-78_timeSeries.csv'#26#too big for github
#          ,'PCTOT_01-31-2023 17-02-07-08_timeSeries/PCTOT_01-31-2023 17-02-07-08_timeSeries.csv'#29#too big for github
#          ,'WHDREO_02-06-2023 03-53-04-14_timeSeries/WHDREO_02-06-2023 03-53-04-14_timeSeries.csv' #31#too big for github
#          ,'WoRLD_02-08-2023 01-04-45-48_timeSeries/WoRLD_02-08-2023 01-04-45-48_timeSeries.csv' #32#too big for github
             ]

# feature_df = pd.DataFrame(columns=['Country Name','Country Code','Indicator Name'
#                                       ,'Indicator Code','Year','Feature Value','filename'])
train_year = 2020
inputdate = '2023-04-04'

train_y_df =model_df[[train_year+1]].replace('no data',0).fillna(0)
test_y_df =model_df[[train_year+2]].replace('no data',0).fillna(0)

completed_file_dfs_sample = [
              'BOPAGG_02-04-2023 07-59-39-92_timeSeries/BOPAGG_02-04-2023 07-59-39-92_timeSeries.csv'#3
         ,'CDIS_01-15-2023 18-58-45-21_timeSeries/CDIS_01-15-2023 18-58-45-21_timeSeries.csv'
        #  ,'CPI_02-07-2023 16-19-35-85_timeSeries/CPI_02-07-2023 16-19-35-85_timeSeries.csv'#6
        #  ,'ED_02-07-2023 04-41-04-68_timeSeries/ED_02-07-2023 04-41-04-68_timeSeries.csv'#8
        # ,'FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries/FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries.csv'
        # ,'FM_02-07-2023 04-43-40-20_timeSeries/FM_02-07-2023 04-43-40-20_timeSeries.csv'#13
        #  ,'FSI_02-03-2023 08-19-04-78_timeSeries/FSI_02-03-2023 08-19-04-78_timeSeries.csv'#14
        #  ,'FSIRE_02-04-2023 08-23-40-70_timeSeries/FSIRE_02-04-2023 08-23-40-70_timeSeries.csv'#15
        #  ,'GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries/GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries.csv'#16
        #  ,'GFSCOFOG_02-07-2023 04-44-34-74_timeSeries/GFSCOFOG_02-07-2023 04-44-34-74_timeSeries.csv'
        #  ,'GFSE_02-07-2023 04-44-54-86_timeSeries/GFSE_02-07-2023 04-44-54-86_timeSeries.csv'#18
        #  ,'GFSFALCS_02-07-2023 04-45-22-02_timeSeries/GFSFALCS_02-07-2023 04-45-22-02_timeSeries.csv'
        #  ,'GFSIBS_02-06-2023 14-42-18-39_timeSeries/GFSIBS_02-06-2023 14-42-18-39_timeSeries.csv'
        #  ,'GFSMAB_02-07-2023 04-46-16-64_timeSeries/GFSMAB_02-07-2023 04-46-16-64_timeSeries.csv'
        #  ,'GFSR_02-07-2023 04-46-55-75_timeSeries/GFSR_02-07-2023 04-46-55-75_timeSeries.csv'
        #  ,'GFSSSUC_02-07-2023 04-47-28-17_timeSeries/GFSSSUC_02-07-2023 04-47-28-17_timeSeries.csv'
        #  ,'HPDD_04-11-2020 23-37-06-60_timeSeries/HPDD_04-11-2020 23-37-06-60_timeSeries.csv'#24
        #  ,'IFS_02-07-2023 12-51-31-57_timeSeries/IFS_02-07-2023 12-51-31-57_timeSeries.csv'#25
        #  ,'IRFCL_02-07-2023 08-35-05-78_timeSeries/IRFCL_02-07-2023 08-35-05-78_timeSeries.csv'#26
        #  ,'PCTOT_01-31-2023 17-02-07-08_timeSeries/PCTOT_01-31-2023 17-02-07-08_timeSeries.csv'#29
        #  ,'WHDREO_02-06-2023 03-53-04-14_timeSeries/WHDREO_02-06-2023 03-53-04-14_timeSeries.csv' #31
        #  ,'WoRLD_02-08-2023 01-04-45-48_timeSeries/WoRLD_02-08-2023 01-04-45-48_timeSeries.csv' #32
            ]

iso_country_codes = {
    'Afghanistan':4,
	'Albania':8,	
	'Algeria':12,
	'American Samoa':16,
	'Andorra':20	,
	'Angola':24,
	'Antigua and Barbuda':28,
	'Argentina':32,
    'Armenia':51,
    'Aruba':533,
	'Australia':36,
	'Austria':40,
    'Azerbaijan':31,
    'Bahamas, The':44,
    'Bahrain':48,	
	'Bangladesh':50,
    'Barbados':52,
    'Belarus':112,
	'Belgium':56,
    'Belize':84,
    'Benin':204,
	'Bermuda':60,
	'Bhutan':64,	
	'Bolivia':68,
	'Bosnia and Herzegovina':70,
	'Botswana':72,
    'Brazil':76,
    'Brunei Darussalam':96,
	'Bulgaria':100,
    'Burkina Faso':854,
    'Burma':104,
    'Burundi':108,
    'Cabo Verde':132,
	'Cambodia':116,
	'Cameroon':120,
    'Canada':124,
    'Central African Republic':140,
    'Chad':148,
    'Chile':152,
    "China, People's Republic of":156,
	'Colombia':170,
	'Comoros':174,
	'Congo, Republic of ':178,	
	'Congo, Dem. Rep. of the':180,
    'Costa Rica':188,
    "Côte d'Ivoire":384,
	'Croatia':191,	
	'Cuba':192,	
	'Cyprus':196,	
	'Czech Republic':203,
    'Denmark':208,	
    'Djibouti':262,
	'Dominica':212,
	'Dominican Republic':214,
	'Ecuador':218,
    'Egypt':818,
	'El Salvador':222,
	'Equatorial Guinea':226,
	'Eritrea':232,
	'Estonia':233,
    'Eswatini':748,
    'Ethiopia':231,
	'Falkland Islands':238,
	'Faroe Islands':234,
	'Fiji':242,
    'Finland':246,
    'France':250,
	'Gabon':266,
	'Gambia, The':270,	
	'Georgia':268,
    'Germany':276,
    'Ghana':288,
    'Greece':300,
	'Grenada':308,
	'Guadeloupe':312,
	'Guam':316,
	'Guatemala':320,
	'Guernsey':831,
	'Guinea':324,
	'Guinea-Bissau':624,
	'Guyana':328,
    'Haiti':332,
    'Honduras':340,
    'Hong Kong SAR':344,
    'Hungary':348,
    'Iceland':352,
    'India':356,
	'Indonesia':360,
	'Iran':364,
	'Iraq':368,
	'Ireland':372,
	'Israel':376,
	'Italy':380,
	'Jamaica':388,
	'Japan':392,
	'Jordan':400,
	'Kazakhstan':398,
	'Kenya':404,
	'Kiribati':296,
	"Korea (Democratic People's Republic of)":408,
	"Korea, Republic of":410,
    'Kosovo':None,
	'Kuwait':414,
	'Kyrgyz Republic':417,
	"Lao P.D.R.":418,	
	'Latvia':428,
	'Lebanon':422,
	'Lesotho':426,
	'Liberia':430,
	'Libya':434,
	'Liechtenstein':438,
	'Lithuania':440,
	'Luxembourg':442,
	'Macao SAR':446,
	'Madagascar':450,
	'Malawi':454,
	'Malaysia':458,
	'Maldives':462,
	'Mali':466,
	'Malta':470,
	'Marshall Islands':584,
	'Mauritania':478,	
	'Mauritius':480,
	'Mexico':484,
	'Micronesia, Fed. States of':583,
	'Moldova':498,
	'Monaco':492,
	'Mongolia':496,
	'Montenegro':499,
	'Montserrat':500,
	'Morocco':504,
	'Mozambique':508,
	'Namibia':516,
	'Nauru':520,
	'Nepal':524,
	'Netherlands':528,
	# 'New Caledonia':540,
	'New Zealand':554,
	'Nicaragua':558,
	'Niger':562,
	'Nigeria':566,
	'Niue':570,
	'Norfolk Island':574,
	'North Macedonia ':807,
	'Northern Mariana Islands':580,
	'Norway':578,
    'Oman':512,
	'Pakistan':586,
	'Palau':585,
	# 'Palestine, State of':275,
	'Panama':591,
	'Papua New Guinea':598,
	'Paraguay':600,
	'Peru':604,
	'Philippines':608,
	'Pitcairn':612,
	'Poland':616,
	'Portugal':620,
	'Puerto Rico':630,
	'Qatar':634,	
	'Romania':642,
	'Russian Federation':643,
    'Rwanda':646,
    'Saint Kitts and Nevis':659,
	'Saint Lucia':662,
	'Saint Martin':663,
	'Saint Pierre and Miquelon':666,
	'Saint Vincent and the Grenadines':670,
	'Samoa':882,
	'San Marino':674,
	'São Tomé and Príncipe':678,
	'Saudi Arabia':682,
	'Senegal':686,
	'Serbia':688,
	'Seychelles':690,
	'Sierra Leone':694,
	'Singapore':702,
	'Slovak Republic':703,
	'Slovenia':705,
	'Solomon Islands':90,
	'Somalia':706,
	'South Africa':710,
	'South Georgia':239,
    'South Sudan, Republic of':728,
    'Spain':724,	
	'Sri Lanka':144,
	'Sudan':729,
	'Suriname':740,
	'Sweden':752,
	'Switzerland':756,
	'Syria':760,#Syrian Arab Republic	
	'Taiwan':158,
	'Tajikistan':762,
	'Tanzania':834,
	'Thailand':764,
	'Timor-Leste':626,
	'Togo':768,
	'Tonga':776,
	'Trinidad and Tobago':780,
	'Tunisia':788,
	'Türkiye, Republic of':792,
	'Turkmenistan':795,
	'Tuvalu':798,
	'Uganda':800,
	'Ukraine':804,
	'United Arab Emirates':784,
	'United Kingdom':826,
	'United States':840,
	'Uruguay':858,
	'Uzbekistan':860,
	'Vanuatu':548,
	'Venezuela':862,
	'Vietnam':704,
    'West Bank and Gaza':275,
	'Yemen':887,
	'Zambia':894,
	'Zimbabwe':716
    # ,'nan':None
}


def choropleth_dfs(test_y, train_year, predictions):
    choropleth_df = test_y.copy().astype(float)
    choropleth_df['Country Name'] = choropleth_df.index
    choropleth_df['GDP Per Capita'] = [x for x in predictions]
    choropleth_df['id'] = [iso_country_codes[x] for x in choropleth_df.index]

    choropleth_actual_df = choropleth_df[['Country Name',train_year+2,'id']]
    choropleth_actual_df.rename(columns={train_year+2:'GDP Per Capita'},inplace=True)
    choropleth_actual_df = choropleth_actual_df[['Country Name','GDP Per Capita','id']]

    choropleth_df = choropleth_df[['Country Name','GDP Per Capita','id']]
    return choropleth_df, choropleth_actual_df

def choropleth_chart(test_y, train_year,predictions, model, model_score,rmse):
    choropleth_df, choropleth_actual_df = choropleth_dfs(test_y, train_year, predictions)
    gdpactual= alt.Chart(
        world
          , title = ["Actual GDP Per Capita"
                    ,'for Year: ' + str(train_year +2)]).mark_geoshape(stroke='black' #'white'
                                                                ,fillOpacity=1,strokeWidth=.05).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=choropleth_actual_df, key = 'id', fields=['id','Country Name','GDP Per Capita'])
    ).encode(
    # tooltip='properties.geounit:N',
    color=alt.Color('GDP Per Capita:Q'
                    ,scale= alt.Scale(domain=[
                                                # 0,100000
                                            choropleth_actual_df['GDP Per Capita'].min()
                                              ,choropleth_actual_df['GDP Per Capita'].max()
                                              ]
                                        # ,range=['red','yellow','green']
                                        ,range=['lightgreen','darkblue']
                                      ))
    , tooltip=['Country Name:N', 'GDP Per Capita:Q']

    ).project(
    type='mercator'
    ).properties(
    width=800,
    height=800
    )
    gdpactual#.show()

    gdpforecast= alt.Chart(
        world
          , title = ["GDP Per Capita Forecasting : "
                    ,'Forecast Year: ' + str(train_year +2) 
                    ,'Model: '+model.__class__.__name__+ ' Score: '+str(round(model_score,4))
                    +' RMSE: '+str(rmse)]
                    ).mark_geoshape(stroke='black' #'white'
                                    ,fillOpacity=1,strokeWidth=.05).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=choropleth_df, key = 'id', fields=['id','Country Name','GDP Per Capita'])
    ).encode(
    # tooltip='properties.geounit:N',
    color=alt.Color('GDP Per Capita:Q'
                    ,scale= alt.Scale(domain=[
                                           # 0
                                        choropleth_df['GDP Per Capita'].min()
                                              ,choropleth_df['GDP Per Capita'].max()]
                                        # ,range=['red','yellow','green']
                                        ,range=['lightgreen','darkblue']
                                      ))
    , tooltip=['Country Name:N', 'GDP Per Capita:Q']

    ).project(
    type='mercator'
    ).properties(
    width=800,
    height=800
    )
    gdpforecast#.show()
    return alt.hconcat(gdpactual, gdpforecast)#.show()

def decision_tree_kfold(train_X, train_y, test_X, test_y, code_names, max_features, max_depth, ccp_alpha, trainindex, testindex):
    # print('decision tree: ')

    # print(train_X)
    # print(train_y)

    percent_threshold = 0.00009

    dt_regr = DecisionTreeRegressor(max_features= max_features, max_depth= max_depth, ccp_alpha = ccp_alpha).fit(pd.DataFrame(train_X).iloc[trainindex,:], pd.DataFrame(train_y).iloc[trainindex,:])
    dt_regr_score = dt_regr.score(pd.DataFrame(train_X).iloc[testindex,:], pd.DataFrame(train_y).iloc[testindex,:])
    dt_regr_predict = dt_regr.predict(pd.DataFrame(test_X).iloc[:,:])

    rmse = round(math.sqrt(mean_squared_error(test_y, dt_regr_predict)),3)
    # print(dt_regr_score,rmse)

    # print([list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold])

    dt_col_results = pd.DataFrame(columns = ['model','filename', 'max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])

    for sig_i, sig_column in enumerate([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]]):
        # print(round([dt_regr.feature_importances_[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]][sig_i],4)
        #       ,sig_column
        #     , metadata_df[metadata_df['Indicator Code']==sig_column]['Indicator Name'].unique()[0]
        #     ,metadata_df[metadata_df['Indicator Code']==sig_column]['filename'].unique()[0]
        #     )
        col_score = round([dt_regr.feature_importances_[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]][sig_i],4)
        col_df = pd.DataFrame([[dt_regr.__class__.__name__, df_file[df_file['Indicator Code']==sig_column]['filename'].unique()[0]
                                , max_features, max_depth, ccp_alpha, dt_regr_score, rmse ,sig_column, col_score
                               ,df_file[df_file['Indicator Code']==sig_column]['Indicator Name'].unique()[0]]]
                               ,columns = ['model','filename', 'max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
        dt_col_results = pd.concat([dt_col_results, col_df], axis = 0)
        # print(dt_col_results) 
    # dt_results = pd.concat([dt_results,dt_col_results],axis = 0)
    return dt_regr, dt_regr_predict, dt_regr_score, rmse, dt_col_results

def k_unsup(train_X_standard, train_y, test_X_standard):
    print('k unsupervised: ')


    highest_kneighbors_score = [2,-1]
    highest_kmeans_score = [2,-1,-1]

    kmeans_results = pd.DataFrame(columns = ['Cluster','Inertia','Silhouette Score','K Neighbore Score'])

    for x in range(2,22):
        # print(x)
        kneigh = KNeighborsRegressor(n_neighbors=x)
        kneigh.fit(train_X_standard, train_y)

        kneighscore = kneigh.score(train_X_standard,train_y) 
        kmeans = KMeans(n_clusters = x)
        kmeans.fit(train_X_standard, train_y)

        kmeansscore = kmeans.score(train_X_standard, train_y)

        silhouettescore = round(silhouette_score(train_X_standard, kmeans.labels_),4)
        # print(silhouettescore)
        inertia = round(kmeans.inertia_)
        cluster_df = pd.DataFrame([[x,inertia,silhouettescore,kneighscore]],columns = ['Cluster','Inertia','Silhouette Score','K Neighbor Score'])
        kmeans_results=kmeans_results.append(cluster_df)

        if kneighscore > highest_kneighbors_score[1]:
            highest_kneighbors_score[0] = x
            highest_kneighbors_score[1] = np.round(kneighscore,4)
        if silhouettescore > highest_kmeans_score[1]:
            highest_kmeans_score[0] = x
            highest_kmeans_score[1] = silhouettescore #silhouette_score(X,kmeans.labels_)
            highest_kmeans_score[2]=kmeans.inertia_


    kmeans = KMeans(n_clusters = highest_kmeans_score[0])
    # kmeans = KMeans(n_clusters = highest_kmeans_score[0],algorithm = 'elkan') 
    kmeans.fit(train_X_standard,train_y)
    # kmeans.fit(nca_pca.transform(train_X_standard), train_y_label_encoded)

    kneigh = KNeighborsRegressor(n_neighbors=highest_kneighbors_score[0]).fit(train_X_standard, train_y)#, weights = 'distance', algorithm = 'ball_tree', 'kd_tree', 'brute'
 
    kneighpredict = kneigh.predict(test_X_standard)

    return kneighpredict, kmeans_results, highest_kneighbors_score, highest_kmeans_score

def kneigh_results_charts(kneigh_results, highest_kneighbors_score, highest_kmeans_score):

    kneighbor_chart = alt.Chart(kneigh_results,title=["K-Neighbor Model Results"
                                                       ,'Highest K-Neighbor Score: '+str(highest_kneighbors_score[1])
                                                       + ' at cluster: ' + str(highest_kneighbors_score[0])]
                                                       ).mark_line().encode(
        x=alt.X('Cluster:N'),
        y = alt.Y('K Neighbor Score:Q')
    ).properties(
        width=400,
        height=300
    )

    silhouette_chart = alt.Chart(kneigh_results,title=[file_name.split('_')[0]
                                                        ,"K-Means Model Silhouette Results" 
                                                       ,'Highest K-Means Score: '+str(highest_kmeans_score[1])
                                                       + ' at cluster: ' + str(highest_kmeans_score[0]) ] ).mark_line().encode(
        x=alt.X('Cluster:N'),
        y = alt.Y('Silhouette Score:Q')
    ).properties(
        width=400,
        height=300
    )

    inertia_chart = alt.Chart(kneigh_results,title=["K-Means Model Inertia Results" 
                                                    ,'Highest K-Means Score: '+str(highest_kmeans_score[1])
                                                       + ' at cluster: ' + str(highest_kmeans_score[0])
                                                    ,'with an inertia of: '+str(highest_kmeans_score[2])]).mark_line().encode(
    x=alt.X('Cluster:N'),
    y = alt.Y('Inertia:Q')
   ).properties(
    width=400,
    height=300
    )

    alt.hconcat(kneighbor_chart,silhouette_chart, inertia_chart).show()

def k_unsup_choropleth(k_predictions, test_y):
    # print(df)
    k_predictions = pd.DataFrame(k_predictions)
    gdppc_chart_df = k_predictions.copy()
    gdppc_chart_df = gdppc_chart_df[[train_year+2]].rename(columns={train_year+2:'GDP Per Capita'}).replace('no data',0).fillna(0).astype(float)
    gdppc_chart_df['Country Name'] = gdppc_chart_df.index
    gdppc_chart_df['id'] = [iso_country_codes[x] for x in gdppc_chart_df.index]


    gdppc= alt.Chart(
        world
          , title = ["GDP Per Capita : "
                    ,'Year: ' + str(train_year+2)]
                    ).mark_geoshape(stroke='black' #'white' 
                                    ,fillOpacity=1,strokeWidth=.05).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=gdppc_chart_df, key = 'id', fields=['id','Country Name','GDP Per Capita'])
    ).encode(
    # tooltip='properties.geounit:N',
    color=alt.Color('GDP Per Capita:Q'
                    ,scale= alt.Scale(domain=[
                                           # 0
                                        gdppc_chart_df['GDP Per Capita'].min()
                                              ,gdppc_chart_df['GDP Per Capita'].max()]
                                        ,range=['lightgreen','darkblue']
                                      ))
                ,size=alt.Size('GDP Per Capita Predicted:Q',legend = alt.Legend(title='GDP Per Capita'))                                      
    , tooltip=['Country Name:N', 'GDP Per Capita:Q']

    ).project(
    type='mercator'
    ).properties(
    width=800,
    height=800
    )
    gdppc#.show()

pca_train_df = pd.DataFrame(index = train_y_df.index)
pca_test_df = pd.DataFrame(index = test_y_df.index)

print(pca_train_df)
print(pca_test_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Afghanistan, Albania, Algeria, Andorra, Angola, Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, The, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, Brazil, Brunei Darussalam, Bulgaria, Burkina Faso, Burma, Burundi, Cabo Verde, Cambodia, Cameroon, Canada, Central African Republic, Chad, Chile, China, People's Republic of, Colombia, Comoros, Congo, Dem. Rep. of the, Congo, Republic of , Costa Rica, Croatia, Cyprus, Czech Republic, Côte d'Ivoire, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Eswatini, Ethiopia, Fiji, Finland, France, Gabon, Gambia, The, Georgia, Germany, Ghana, Greece, Grenada, Guatemala, Guinea, Guinea-Bissau, Guyana, Haiti, Honduras, Hong Kong SAR, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Israel, Italy, Jamaica, Japan, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Republic of, Kosovo, Kuwait, Kyrgyz Republic, Lao P.D.R., Latvia, Lebanon, Lesotho, Liberia, ...]
#
# [196 rows x 0 columns]
# Empty DataFrame
# Columns: []
# Index: [Afghanistan, Albania, Algeria, Andorra, Angola, Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, The, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, Brazil, Brunei Darussalam, Bulgaria, Burkina Faso, Burma, Burundi, Cabo Verde, Cambodia, Cameroon, Canada, Central African Republic, Chad, Chile, China, People's Republic of, Colombia, Comoros, Congo, Dem. Rep. of the, Congo, Republic of , Costa Rica, Croatia, Cyprus, Czech Republic, Côte d'Ivoire, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Eswatini, Ethiopia, Fiji, Finland, France, Gabon, Gambia, The, Georgia, Germany, Ghana, Greece, Grenada, Guatemala, Guinea, Guinea-Bissau, Guyana, Haiti, Honduras, Hong Kong SAR, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Israel, Italy, Jamaica, Japan, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Republic of, Kosovo, Kuwait, Kyrgyz Republic, Lao P.D.R., Latvia, Lebanon, Lesotho, Liberia, ...]
#
# [196 rows x 0 columns]

# %% [markdown]
# Looping through folder/topic data sets, performing prinicipal component analysis on each folder/group of metrics topics, and then combining all of the PCAs from each folder/topic into one dataset. Corrrelation charts for each folder are also produced.

# %%
dataset_corr_charts_dic = {}
meta_dict = {}
for file_name in completed_file_dfs:
# for file_name in completed_file_dfs_sample:
    # start_time = time.perf_counter()
    print(file_name, completed_file_dfs.index(file_name))
    print(course_file_path+file_name.split('/')[0]+'/'+file_name.split('_')[0])
    df_file = pd.read_csv(course_file_path+file_name.split('/')[0]+'/'+file_name.split('_')[0]+'_df.csv')
    meta_of_df = pd.read_csv(course_file_path+file_name.split('/')[0]+'/metadata_'+file_name.split('/')[1])
    meta_subject = meta_of_df[meta_of_df['Metadata Attribute']=='Dataset']['Metadata Value']
    print(meta_subject)
    meta_dict[file_name.split('_')[0]] = meta_subject[1]

    meta_dict['ED'] = 'Export Diversification (ED)'
    meta_dict['EQ'] = 'Export Quality (EQ)'
    meta_dict['FSI'] = 'Financial Soundness Indicators (FSI)'
    meta_dict['FSIRE'] = 'Financial Soundness Indicators Reporting Entities (FSI)'
    meta_dict['GFSCOFOG'] = 'Government Financial Statistics Expenditure by Function of Government (GFSCOFOG)'
    meta_dict['GFSE'] = 'Government Financial Statistics Expense (GFSE)'
    meta_dict['GFSFALCS'] = 'Government Financial Statistics Financial Assets and Liabilities Counterpart (GFSFALCS)'
    meta_dict['GFSIBS'] = 'Government Financial Statistics Integrated Balance Sheet (GFSIBS)'
    meta_dict['GFSMAB'] = 'Government Financial Statistics Main Aggregates and Balances (GFSMAB)'
    meta_dict['GFSR'] = 'Government Financial Statistics Revenue (GFSR)'
    meta_dict['GFSSSUC'] = 'Government Financial Statistics Statement of Sources and Uses of Cash (GFSSSUC)'

    file_index = completed_file_dfs.index(file_name)

    df_file = df_file[['Country Name','Country Code','Indicator Name','Indicator Code','Year','Feature Value','filename']]
    column_exclusion_list = ['Xgdppc']
    df_file = df_file[~df_file['Indicator Code'].isin(column_exclusion_list)]

    train_data_df = df_file[df_file['Year'] <= train_year]
    train_data_df = train_data_df[['Country Name','Indicator Code','Feature Value']]
    train_data_df = pd.pivot_table(train_data_df, values = 'Feature Value'
                                   ,index = ['Country Name']
                                   ,columns = ['Indicator Code']
                                   ,aggfunc=np.mean).fillna(0).astype(float)

    # train_data_df = np.read_csv(course_file_path+'train_feature_data_'+str(train_year)+'_'+str(date.today())+'.csv')


    test_data_df = df_file[df_file['Year'] <= train_year+1]
    test_data_df = test_data_df[['Country Name','Indicator Code','Feature Value']]
    test_data_df = test_data_df[['Country Name','Indicator Code','Feature Value']]
    test_data_df = pd.pivot_table(test_data_df, values = 'Feature Value'
                                   ,index = ['Country Name']
                                   ,columns = ['Indicator Code']
                                   ,aggfunc=np.mean).fillna(0).astype(float)
    

    train_data_df = train_y_df.merge(train_data_df  , left_on='Country Name', right_on='Country Name', how='inner')#.reset_index()
    train_X = train_data_df.drop(columns =[train_year+1])

    
    test_data_df = test_y_df.merge(test_data_df  , left_on='Country Name', right_on='Country Name', how='inner')#.reset_index()
    test_X = test_data_df.drop(columns =[train_year+2])
    test_X = test_data_df

    feature_list = [x for x in train_X.columns]
    feature_list = [x for x in feature_list if x in test_X.columns]

    train_X = train_X[feature_list].astype(float)
    test_X = test_X[feature_list].astype(float)

    train_y = train_data_df[[train_year+1]].astype(float)
    test_y = test_data_df[[train_year+2]].astype(float)

    train_X_scaled = StandardScaler().fit(train_X).transform(train_X)#.astype(float)
    train_X_scaled = add_constant(train_X_scaled)

    test_X_scaled = StandardScaler().fit(test_X).transform(test_X)#.astype(float)
    test_X_scaled = add_constant(test_X_scaled)

    train_y_label_encoded = preprocessing.LabelEncoder().fit_transform(train_y)
    test_y_label_encoded = preprocessing.LabelEncoder().fit_transform(test_y)

    folder_corr_df = pd.DataFrame(abs(train_X.corr()), index = train_X.columns, columns = train_X.columns)
    folder_corrMatrix = folder_corr_df.reset_index().melt('index')
    folder_corrMatrix.columns = ['var1', 'var2', 'correlation']
    folder_corrMatrix.sort_values(by=['correlation'],ascending=True,inplace=True)
    folder_corrMatrix['model'] = 'correlation matrix'

    folder_corrMatrix_heatmap = folder_corrMatrix[:5000]

    folder_corr_chart = alt.Chart(folder_corrMatrix_heatmap, title = ["Feature Correlation Heatmap of "+meta_dict[file_name.split('_')[0]]+" Features: "
                    ,'Number of Principal Components: '+str(folder_corr_df.shape[0]) 
                    ,'PCA Confidence Interval: ']
                    ).mark_rect().encode(
    x='var2:O',
    y='var1:O'
    ,color='correlation:Q'
    , tooltip=['correlation:Q'],
    ).properties(height=250, width = 250)#.show()
    
    dataset_corr_charts_dic[completed_file_dfs.index(file_name)] = folder_corr_chart

    ci = .95
    svd_solver = 'auto'#'full'
    nca_pca = PCA(n_components=ci, svd_solver=svd_solver)
    # nca_pca.fit(nca_pca.transform(train_X), train_y_label_encoded)
    nca_pca.fit(train_X, train_y_label_encoded)

    print(nca_pca.get_params(deep=True))

    print(nca_pca.transform(train_X).shape)
   
    print(nca_pca.components_.shape)

    folder_train_pca_df = pd.DataFrame(nca_pca.transform(train_X)
                                 ,columns = [file_name.split('_')[0]+'_component_'+str(x) for x in range(nca_pca.components_.shape[0])]
                                 ,index=train_X.index)
    folder_test_pca_df = pd.DataFrame(nca_pca.transform(test_X)
                                 ,columns = [file_name.split('_')[0]+'_component_'+str(x) for x in range(nca_pca.components_.shape[0])]
                                 ,index=test_X.index)

    # print(nca_pca.transform(train_X).shape)
    # print(folder_train_pca_df)
    pca_train_df = pd.concat([pca_train_df, folder_train_pca_df],axis= 1).fillna(0)
    pca_test_df = pd.concat([pca_test_df, folder_test_pca_df],axis= 1).fillna(0)

alt.vconcat(
alt.hconcat(dataset_corr_charts_dic[0],dataset_corr_charts_dic[1]),
alt.hconcat(dataset_corr_charts_dic[2],dataset_corr_charts_dic[3]),
alt.hconcat(dataset_corr_charts_dic[4],dataset_corr_charts_dic[5]),
alt.hconcat(dataset_corr_charts_dic[6],dataset_corr_charts_dic[7])
)
# Out:
# BOPAGG_02-04-2023 07-59-39-92_timeSeries/BOPAGG_02-04-2023 07-59-39-92_timeSeries.csv 0
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/BOPAGG_02-04-2023 07-59-39-92_timeSeries/BOPAGG
# 1    Balance of Payments (BOP)
# Name: Metadata Value, dtype: object
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (187, 1)
# (1, 37)
# CDIS_01-15-2023 18-58-45-21_timeSeries/CDIS_01-15-2023 18-58-45-21_timeSeries.csv 1
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/CDIS_01-15-2023 18-58-45-21_timeSeries/CDIS
# 1    Coordinated Direct Investment Survey (CDIS)
# Name: Metadata Value, dtype: object
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (196, 4)
# (4, 40)
# ED_02-07-2023 04-41-04-68_timeSeries/ED_02-07-2023 04-41-04-68_timeSeries.csv 2
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/ED_02-07-2023 04-41-04-68_timeSeries/ED
# 1    Export Diversification and Quality
# Name: Metadata Value, dtype: object
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (184, 2)
# (2, 3)
# EQ_02-04-2023 18-05-06-26_timeSeries/EQ_02-04-2023 18-05-06-26_timeSeries.csv 3
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/EQ_02-04-2023 18-05-06-26_timeSeries/EQ
# 1    Export Diversification and Quality
# Name: Metadata Value, dtype: object
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /var/folders/7l/v039n9y14dl1p58v4l2n14_r0000gn/T/ipykernel_33947/3895278604.py:78: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   folder_corrMatrix = folder_corr_df.reset_index().melt('index')
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (165, 1)
# (1, 9)
# FAS_02-04-2023 13-20-29-76_timeSeries/FAS_02-04-2023 13-20-29-76_timeSeries.csv 4
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/FAS_02-04-2023 13-20-29-76_timeSeries/FAS
# 1    Financial Access Survey (FAS)
# Name: Metadata Value, dtype: object
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (187, 1)
# (1, 191)
# FDI_07-14-2022 10-45-25-27_timeSeries/FDI_07-14-2022 10-45-25-27_timeSeries.csv 5
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/FDI_07-14-2022 10-45-25-27_timeSeries/FDI
# 1    Financial Development (FD)
# Name: Metadata Value, dtype: object
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (182, 4)
# (4, 9)
# FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries/FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries.csv 6
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/FISCALDECENTRALIZATION_11-13-2022 06-45-12-25_timeSeries/FISCALDECENTRALIZATION
# 1    Fiscal Decentralization
# Name: Metadata Value, dtype: object
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (86, 4)
# (4, 144)
# FM_02-07-2023 04-43-40-20_timeSeries/FM_02-07-2023 04-43-40-20_timeSeries.csv 7
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/FM_02-07-2023 04-43-40-20_timeSeries/FM
# 1    Fiscal Monitor (FM)
# Name: Metadata Value, dtype: object
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (193, 3)
# (3, 8)
# FSI_02-03-2023 08-19-04-78_timeSeries/FSI_02-03-2023 08-19-04-78_timeSeries.csv 8
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/FSI_02-03-2023 08-19-04-78_timeSeries/FSI
# 1    Financial Soundness Indicators (FSI)
# Name: Metadata Value, dtype: object
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (141, 1)
# (1, 1311)
# FSIRE_02-04-2023 08-23-40-70_timeSeries/FSIRE_02-04-2023 08-23-40-70_timeSeries.csv 9
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/FSIRE_02-04-2023 08-23-40-70_timeSeries/FSIRE
# 1    Financial Soundness Indicators (FSI)
# Name: Metadata Value, dtype: object
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (96, 2)
# (2, 812)
# GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries/GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries.csv 10
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/GENDER_EQUALITY_01-25-2023 14-59-11-92_timeSeries/GENDER
# 1    Gender
# Name: Metadata Value, dtype: object
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (156, 2)
# (2, 2)
# HPDD_04-11-2020 23-37-06-60_timeSeries/HPDD_04-11-2020 23-37-06-60_timeSeries.csv 11
# /Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/HPDD_04-11-2020 23-37-06-60_timeSeries/HPDD
# 1    Historical Public Debt (HPDD)
# Name: Metadata Value, dtype: object
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# (187, 1)
# (1, 1)
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# alt.VConcatChart(...)

# %% [markdown]
# Final training data set containing all principal components from all data set folders/metrics groups

# %%
# meta_dict['ED'] = 'Export Diversification (ED)'
# meta_dict['EQ'] = 'Export Quality (EQ)'
# meta_dict['FSI'] = 'Financial Soundness Indicators (FSI)'
# meta_dict['FSIRE'] = 'Financial Soundness Indicators Reporting Entities (FSI)'
# meta_dict['GFSCOFOG'] = 'Government Financial Statistics Expenditure by Function of Government (GFSCOFOG)'
# meta_dict['GFSE'] = 'Government Financial Statistics Expense (GFSE)'
# meta_dict['GFSFALCS'] = 'Government Financial Statistics Financial Assets and Liabilities Counterpart (GFSFALCS)'
# meta_dict['GFSIBS'] = 'Government Financial Statistics Integrated Balance Sheet (GFSIBS)'
# meta_dict['GFSMAB'] = 'Government Financial Statistics Main Aggregates and Balances (GFSMAB)'
# meta_dict['GFSR'] = 'Government Financial Statistics Revenue (GFSR)'
# meta_dict['GFSSSUC'] = 'Government Financial Statistics Statement of Sources and Uses of Cash (GFSSSUC)'

# train_year = 2017
# process_data_for_model(train_year, '2023-04-04')

print(pca_train_df)
print(pca_test_df)
# Out:
#                     BOPAGG_component_0  CDIS_component_0  CDIS_component_1  \
# Country Name
# Afghanistan              -1.009622e+12     -1.244520e+10      3.623285e+09
# Albania                  -1.004732e+12     -1.201411e+10      3.386319e+09
# Algeria                  -8.919966e+11     -1.173755e+10      3.144935e+09
# Andorra                  -1.001883e+12     -1.242353e+10      3.607022e+09
# Angola                   -9.338461e+11     -1.146556e+10      2.967117e+09
# ...                                ...               ...               ...
# Vietnam                  -9.804472e+11     -1.106985e+10      2.712225e+09
# West Bank and Gaza       -1.010567e+12     -1.224426e+10      3.475791e+09
# Yemen                    -1.005544e+12     -1.243233e+10      3.616419e+09
# Zambia                   -9.930041e+11     -1.198100e+10      3.460333e+09
# Zimbabwe                 -1.017968e+12     -1.237204e+10      3.574227e+09
#
#                     CDIS_component_2  CDIS_component_3  ED_component_0  \
# Country Name
# Afghanistan             2.217320e+09      1.078783e+09       -0.204351
# Albania                 2.026014e+09      1.116634e+09       -0.018746
# Algeria                 2.039529e+09      4.584487e+08       -2.669987
# Andorra                 2.212787e+09      1.054957e+09       -0.194602
# Angola                  2.064284e+09     -2.999362e+08       -3.235098
# ...                              ...               ...             ...
# Vietnam                 1.988159e+09     -9.012083e+08        0.811641
# West Bank and Gaza      2.071612e+09      1.395561e+09        0.000000
# Yemen                   2.217348e+09      1.054866e+09       -1.936016
# Zambia                  1.855209e+09      1.300425e+09       -2.339368
# Zimbabwe                2.206032e+09      9.756433e+08       -0.063275
#
#                     ED_component_1  EQ_component_0  FAS_component_0  \
# Country Name
# Afghanistan               1.137652        0.000000    -3.051658e+14
# Albania                  -0.490627  -294294.470626    -3.046046e+14
# Algeria                  -0.707981   125383.021483    -3.029202e+14
# Andorra                  -0.430418        0.000000     0.000000e+00
# Angola                   -1.044347   357165.006776    -3.035052e+14
# ...                            ...             ...              ...
# Vietnam                  -0.442165   110283.952503     1.966891e+16
# West Bank and Gaza        0.000000        0.000000    -3.052119e+14
# Yemen                    -0.372619  -175638.958706    -3.048692e+14
# Zambia                   -1.287904  -261431.405941    -3.052006e+14
# Zimbabwe                 -0.656106  -287340.756741    -3.051213e+14
#
#                     FDI_component_0  ...  FISCALDECENTRALIZATION_component_3  \
# Country Name                         ...
# Afghanistan                0.000000  ...                           -2.720219
# Albania                   -0.409813  ...                           -0.721055
# Algeria                   -0.392181  ...                            0.000000
# Andorra                    0.000000  ...                            0.000000
# Angola                    -0.458736  ...                            0.000000
# ...                             ...  ...                                 ...
# Vietnam                    0.031935  ...                            0.000000
# West Bank and Gaza         0.000000  ...                            0.000000
# Yemen                     -0.482550  ...                            0.000000
# Zambia                    -0.208590  ...                            0.000000
# Zimbabwe                   0.000000  ...                            0.000000
#
#                     FM_component_0  FM_component_1  FM_component_2  \
# Country Name
# Afghanistan             -16.920027       14.146496       -5.861169
# Albania                  38.403258      -24.717211      -13.271845
# Algeria                  -2.214252      -13.178381        2.981435
# Andorra                   0.000000        0.000000        0.000000
# Angola                   -9.145989       14.811851       10.556744
# ...                            ...             ...             ...
# Vietnam                 -26.360387        7.107509      -10.659224
# West Bank and Gaza        0.000000        0.000000        0.000000
# Yemen                    24.204460      -20.854130      -15.293816
# Zambia                   27.542330        3.184613      -12.651983
# Zimbabwe                -12.799455       21.086477      -13.599536
#
#                     FSI_component_0  FSIRE_component_0  FSIRE_component_1  \
# Country Name
# Afghanistan            0.000000e+00       0.000000e+00       0.000000e+00
# Albania               -1.203796e+19      -3.596616e+14      -2.140254e+14
# Algeria               -1.203795e+19      -3.572786e+14      -2.019409e+14
# Andorra                0.000000e+00       0.000000e+00       0.000000e+00
# Angola                -1.203796e+19       0.000000e+00       0.000000e+00
# ...                             ...                ...                ...
# Vietnam               -1.203796e+19       3.553507e+15       1.211130e+16
# West Bank and Gaza    -1.203796e+19      -3.617182e+14      -2.139974e+14
# Yemen                  0.000000e+00       0.000000e+00       0.000000e+00
# Zambia                -1.203796e+19       0.000000e+00       0.000000e+00
# Zimbabwe               0.000000e+00       0.000000e+00       0.000000e+00
#
#                     GENDER_component_0  GENDER_component_1  HPDD_component_0
# Country Name
# Afghanistan                   0.478610            0.235617         23.874874
# Albania                      -0.079070           -0.023204          9.221917
# Algeria                       0.197840           -0.003373         -8.015186
# Andorra                       0.000000            0.000000          0.000000
# Angola                        0.000000            0.000000         16.079854
# ...                                ...                 ...               ...
# Vietnam                      -0.057623           -0.053450         11.524462
# West Bank and Gaza           -0.345607            0.180363          0.000000
# Yemen                         0.457140            0.061851         20.104573
# Zambia                        0.249108           -0.028458         61.493922
# Zimbabwe                      0.207107           -0.052011        -10.840574
#
# [196 rows x 104 columns]
#                     BOPAGG_component_0  CDIS_component_0  CDIS_component_1  \
# Country Name
# Afghanistan              -1.009622e+12     -1.244653e+10      3.623999e+09
# Albania                  -1.004083e+12     -1.201871e+10      3.388689e+09
# Algeria                  -8.964797e+11     -1.173826e+10      3.145083e+09
# Andorra                  -1.001883e+12     -1.242150e+10      3.605541e+09
# Angola                   -9.334503e+11     -1.149216e+10      2.984517e+09
# ...                                ...               ...               ...
# Vietnam                  -9.772890e+11     -1.093844e+10      2.626011e+09
# West Bank and Gaza       -1.010285e+12     -1.223274e+10      3.466634e+09
# Yemen                    -1.005544e+12     -1.243329e+10      3.617090e+09
# Zambia                   -9.923886e+11     -1.197455e+10      3.449633e+09
# Zimbabwe                 -1.017968e+12     -1.236087e+10      3.566739e+09
#
#                     CDIS_component_2  CDIS_component_3  ED_component_0  \
# Country Name
# Afghanistan             2.217139e+09      1.081267e+09       -0.204351
# Albania                 2.028188e+09      1.098034e+09       -0.018746
# Algeria                 2.038540e+09      4.683758e+08       -2.669987
# Andorra                 2.212380e+09      1.052592e+09       -0.194602
# Angola                  2.069739e+09     -2.603382e+08       -3.235098
# ...                              ...               ...             ...
# Vietnam                 1.967801e+09     -1.091985e+09        0.811641
# West Bank and Gaza      2.064042e+09      1.410726e+09        0.000000
# Yemen                   2.217674e+09      1.056309e+09       -1.936016
# Zambia                  1.858565e+09      1.283767e+09       -2.339368
# Zimbabwe                2.204154e+09      9.597726e+08       -0.063275
#
#                     ED_component_1  EQ_component_0  FAS_component_0  \
# Country Name
# Afghanistan               1.137652        0.000000    -3.051658e+14
# Albania                  -0.490627  -294294.470626    -3.045388e+14
# Algeria                  -0.707981   125383.021483    -3.028204e+14
# Andorra                  -0.430418        0.000000     0.000000e+00
# Angola                   -1.044347   357165.006776    -3.033777e+14
# ...                            ...             ...              ...
# Vietnam                  -0.442165   110283.952503     2.553743e+16
# West Bank and Gaza        0.000000        0.000000    -3.052117e+14
# Yemen                    -0.372619  -175638.958706    -3.048692e+14
# Zambia                   -1.287904  -261431.405941    -3.051976e+14
# Zimbabwe                 -0.656106  -287340.756741    -3.049286e+14
#
#                     FDI_component_0  ...  FISCALDECENTRALIZATION_component_3  \
# Country Name                         ...
# Afghanistan                0.000000  ...                           -2.720219
# Albania                   -0.409813  ...                           -0.721055
# Algeria                   -0.392181  ...                            0.000000
# Andorra                    0.000000  ...                            0.000000
# Angola                    -0.458736  ...                            0.000000
# ...                             ...  ...                                 ...
# Vietnam                    0.031935  ...                            0.000000
# West Bank and Gaza         0.000000  ...                            0.000000
# Yemen                     -0.482550  ...                            0.000000
# Zambia                    -0.208590  ...                            0.000000
# Zimbabwe                   0.000000  ...                            0.000000
#
#                     FM_component_0  FM_component_1  FM_component_2  \
# Country Name
# Afghanistan             -16.920027       14.146496       -5.861169
# Albania                  38.603054      -24.378641      -13.117877
# Algeria                  -1.159680      -13.371952        2.786150
# Andorra                   0.000000        0.000000        0.000000
# Angola                   -8.200260       15.898462       10.130098
# ...                            ...             ...             ...
# Vietnam                 -26.248809        7.197179      -10.625541
# West Bank and Gaza        0.000000        0.000000        0.000000
# Yemen                    25.059568      -20.655586      -16.125182
# Zambia                   31.641848        1.819601      -12.999474
# Zimbabwe                -12.242070       21.483756      -13.277583
#
#                     FSI_component_0  FSIRE_component_0  FSIRE_component_1  \
# Country Name
# Afghanistan            0.000000e+00       0.000000e+00       0.000000e+00
# Albania               -1.203796e+19      -3.596255e+14      -2.139771e+14
# Algeria               -1.203795e+19      -3.566006e+14      -2.000925e+14
# Andorra                0.000000e+00       0.000000e+00       0.000000e+00
# Angola                -1.203796e+19       0.000000e+00       0.000000e+00
# ...                             ...                ...                ...
# Vietnam               -1.203796e+19       3.962866e+15       1.341221e+16
# West Bank and Gaza    -1.203796e+19      -3.617182e+14      -2.139974e+14
# Yemen                  0.000000e+00       0.000000e+00       0.000000e+00
# Zambia                -1.203796e+19       0.000000e+00       0.000000e+00
# Zimbabwe               0.000000e+00       0.000000e+00       0.000000e+00
#
#                     GENDER_component_0  GENDER_component_1  HPDD_component_0
# Country Name
# Afghanistan                   0.478610            0.235617         23.874874
# Albania                      -0.079070           -0.023204          9.221917
# Algeria                       0.197840           -0.003373         -8.015186
# Andorra                       0.000000            0.000000          0.000000
# Angola                        0.000000            0.000000         16.079854
# ...                                ...                 ...               ...
# Vietnam                      -0.057623           -0.053450         11.524462
# West Bank and Gaza           -0.345607            0.180363          0.000000
# Yemen                         0.457140            0.061851         20.104573
# Zambia                        0.249108           -0.028458         61.493922
# Zimbabwe                      0.207107           -0.052011        -10.840574
#
# [196 rows x 104 columns]

# %% [markdown]
# Target values of countries' GDP Per capita in scope

# %%
print(train_y_df)
print(test_y_df)
# Out:
#                          2021
# Country Name
# Afghanistan             0.000
# Albania              6373.300
# Algeria              3659.531
# Andorra             41873.060
# Angola               2352.128
# ...                       ...
# Vietnam              3717.800
# West Bank and Gaza   3450.571
# Yemen                 644.153
# Zambia               1095.465
# Zimbabwe             2121.568
#
# [196 rows x 1 columns]
#                          2022
# Country Name
# Afghanistan             0.000
# Albania              6369.009
# Algeria              4151.437
# Andorra             40722.630
# Angola               3790.704
# ...                       ...
# Vietnam              4162.938
# West Bank and Gaza   3517.363
# Yemen                 873.903
# Zambia               1348.360
# Zimbabwe             2420.220
#
# [196 rows x 1 columns]

# %% [markdown]
# Performing K10Fold on Decision Tree model which is fitted with all principal components from all data set folder/metric topics.
#
# Results are included averaged across K10Fold with model R, RMSE scores, mean feature significance, and mean country GDP Per Capita predictions.

# %%
# pca_train_df.to_csv(course_file_path+'all_folders_pca_train_'+str(train_year)+'_ci'+str(ci)+'.csv', index=True)
# pca_test_df.to_csv(course_file_path+'all_folders_pca_test_'+str(train_year)+'_ci'+str(ci)+'.csv', index=True)


train_y_df =model_df[[train_year+1]].replace('no data',0).fillna(0).astype(float)
test_y_df =model_df[[train_year+2]].replace('no data',0).fillna(0).astype(float)

train_X = pca_train_df
test_X = pca_test_df

kf10 = KFold(n_splits = 10)
kf10.get_n_splits(train_X)

predictions_avg = pd.DataFrame(index=train_y_df.index)
model_score_results = pd.DataFrame(columns = ['model','max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse'])
col_score_results =pd.DataFrame(columns = ['model','filename','column','avg_column_significance', 'column_descr'])

print('all pca kfold split process: ')
for i, (train_index, test_index) in enumerate(kf10.split(train_X)):
        # print(f"Fold {i}:")
    code_names = pca_train_df.columns
    max_features = 'auto'
    max_depth = 15
    ccp_alpha = .75 #float when increasing from 0 to 1, tree is pruned more to better generalize

    percent_threshold = 0.0009

    dt_regr = DecisionTreeRegressor(max_features= max_features, max_depth= max_depth, ccp_alpha = ccp_alpha).fit(pd.DataFrame(pca_train_df).iloc[train_index,:], pd.DataFrame(train_y_df).iloc[train_index,:])
    dt_regr_score = dt_regr.score(pd.DataFrame(pca_train_df).iloc[test_index,:], pd.DataFrame(train_y_df).iloc[test_index,:])
    dt_regr_predict = dt_regr.predict(pd.DataFrame(pca_test_df).iloc[:,:])

    rmse = round(math.sqrt(mean_squared_error(train_y_df, dt_regr_predict)),3)

    dt_col_results = pd.DataFrame(columns = ['model','filename', 'max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
    # print(dt_regr.feature_importances_)
    print([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]])
    for sig_i, sig_column in enumerate([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]]):
        col_score = round([dt_regr.feature_importances_[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]][sig_i],4)
        col_df = pd.DataFrame([[dt_regr.__class__.__name__, sig_column.split('_')[0]
                                , max_features, max_depth, ccp_alpha, dt_regr_score, rmse ,sig_column, col_score
                                ,meta_dict[sig_column.split('_')[0]]
                               ]]
                               ,columns = ['model','filename', 'max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
        dt_col_results = pd.concat([dt_col_results, col_df], axis = 0)

    model_score_results = pd.concat([model_score_results,dt_col_results[['model','max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse']].drop_duplicates()],axis=0)
    col_score_results = pd.concat([col_score_results,dt_col_results[['model','filename','column','avg_column_significance', 'column_descr']]],axis=0)

        # print(dt_regr_predict)
        # print(test_y_df)
    model_predictions = pd.DataFrame(dt_regr_predict, index=test_y_df.index)
    predictions_avg = pd.concat([predictions_avg, model_predictions],axis=1)

        # print(dt_col_results)
model_score_results=model_score_results.groupby(['model','max_features','max_depth','ccp_alpha'],as_index = False).mean().reset_index()
col_score_results=col_score_results.groupby(['model','filename','column', 'column_descr'],as_index = False)['avg_column_significance'].aggregate(['mean']).reset_index().sort_values(by=['mean'], ascending=False)
print(nca_pca.get_params(deep=True))
print(model_score_results)
print(col_score_results.columns)
print(col_score_results)
print(predictions_avg.mean(axis=1))

# col_score_results['column_descr'] = [meta_dict[x.split('_')[0]][1] for x in col_score_results['column_descr']]
col_score_results['model_avg_r_score'] = model_score_results['avg_r_score'].values[0]
col_score_results['avg_rmse'] = model_score_results['avg_rmse'].values[0]
# model_score_results.to_csv(course_file_path+'all_folders_model_score_results_'+str(train_year)+'_pcaci'+str(int(ci*100))+'.csv', index=True)
# col_score_results.to_csv(course_file_path+'all_folders_col_score_results_'+str(train_year)+'_pcaci'+str(int(ci*100))+'.csv', index=True)
# Out:
# all pca kfold split process:
# ['CDIS_component_0', 'CDIS_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_0', 'GENDER_component_0', 'HPDD_component_0', 'ED_component_1', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_2', 'FM_component_1', 'GENDER_component_0', 'GENDER_component_1', 'BOPAGG_component_0', 'CDIS_component_1', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_2', 'GENDER_component_0', 'ED_component_1', 'EQ_component_0', 'FAS_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_2', 'FM_component_2']
# ['CDIS_component_0', 'EQ_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_3', 'GENDER_component_0', 'HPDD_component_0', 'CDIS_component_1', 'ED_component_0', 'ED_component_1', 'FAS_component_0', 'CDIS_component_3', 'ED_component_1', 'EQ_component_0', 'FAS_component_0', 'FDI_component_0', 'FDI_component_2', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_0', 'FSIRE_component_0', 'GENDER_component_0', 'BOPAGG_component_0', 'CDIS_component_2', 'ED_component_0', 'EQ_component_0', 'FDI_component_1', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_2', 'FSIRE_component_0']
# ['FDI_component_3', 'GENDER_component_0', 'HPDD_component_0', 'BOPAGG_component_0', 'FDI_component_0', 'FDI_component_2', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_2', 'FM_component_2', 'GENDER_component_1', 'CDIS_component_1', 'CDIS_component_2', 'ED_component_0', 'EQ_component_0', 'FDI_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_2', 'FM_component_0', 'GENDER_component_0', 'BOPAGG_component_0', 'CDIS_component_2', 'ED_component_0', 'ED_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_1', 'FM_component_2', 'GENDER_component_0']
# ['BOPAGG_component_0', 'CDIS_component_2', 'FDI_component_1', 'FDI_component_2', 'FM_component_0', 'FM_component_2', 'HPDD_component_0', 'FDI_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_1', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_1', 'ED_component_1', 'FDI_component_1', 'GENDER_component_0', 'GENDER_component_1', 'ED_component_0', 'EQ_component_0', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_2', 'GENDER_component_0', 'HPDD_component_0']
# ['CDIS_component_2', 'FDI_component_2', 'FDI_component_3', 'FSIRE_component_0', 'HPDD_component_0', 'CDIS_component_3', 'ED_component_0', 'EQ_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_2', 'ED_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_1', 'FSI_component_0', 'GENDER_component_0', 'HPDD_component_0', 'CDIS_component_2', 'ED_component_1', 'FDI_component_1', 'FM_component_2', 'HPDD_component_0']
# ['FISCALDECENTRALIZATION_component_2', 'FM_component_0', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_1', 'CDIS_component_3', 'EQ_component_0', 'FM_component_0', 'FM_component_2', 'GENDER_component_1', 'HPDD_component_0', 'FDI_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_2', 'FM_component_2', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'BOPAGG_component_0', 'CDIS_component_2', 'ED_component_0', 'EQ_component_0', 'FDI_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_3', 'GENDER_component_0']
# ['ED_component_1', 'FDI_component_0', 'FDI_component_1', 'FM_component_0', 'GENDER_component_0', 'HPDD_component_0', 'EQ_component_0', 'FDI_component_0', 'FM_component_1', 'FM_component_2', 'FSIRE_component_0', 'GENDER_component_0', 'HPDD_component_0', 'BOPAGG_component_0', 'EQ_component_0', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_2', 'CDIS_component_3', 'FAS_component_0', 'FDI_component_1', 'FDI_component_2', 'FDI_component_3', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0']
# ['CDIS_component_0', 'CDIS_component_3', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_3', 'HPDD_component_0', 'CDIS_component_3', 'FAS_component_0', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_3', 'FM_component_1', 'GENDER_component_0', 'HPDD_component_0', 'CDIS_component_0', 'ED_component_1', 'EQ_component_0', 'FAS_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_2', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_2', 'HPDD_component_0', 'CDIS_component_2', 'FAS_component_0', 'FDI_component_1', 'FDI_component_2', 'GENDER_component_0']
# ['EQ_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_2', 'FDI_component_3', 'GENDER_component_0', 'GENDER_component_1', 'BOPAGG_component_0', 'CDIS_component_0', 'EQ_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_2', 'FM_component_2', 'GENDER_component_0', 'CDIS_component_0', 'CDIS_component_2', 'ED_component_0', 'ED_component_1', 'FAS_component_0', 'FDI_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_2', 'FM_component_2', 'FSIRE_component_1', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_2', 'ED_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_2', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_3', 'FSIRE_component_0', 'GENDER_component_0']
# ['CDIS_component_1', 'ED_component_0', 'FAS_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_1', 'FM_component_2', 'GENDER_component_0', 'GENDER_component_1', 'CDIS_component_2', 'CDIS_component_3', 'FDI_component_1', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_3', 'CDIS_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_2', 'FSIRE_component_1', 'HPDD_component_0', 'ED_component_0', 'ED_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_1', 'FISCALDECENTRALIZATION_component_2', 'GENDER_component_0']
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
#    index                  model max_features  max_depth  ccp_alpha  \
# 0      0  DecisionTreeRegressor         auto         15       0.75
#
#    avg_r_score   avg_rmse
# 0     0.464075  4753.1748
# Index(['model', 'filename', 'column', 'column_descr', 'mean'], dtype='object')
#                     model                filename  \
# 9   DecisionTreeRegressor                     FDI
# 11  DecisionTreeRegressor                     FDI
# 23  DecisionTreeRegressor                  GENDER
# 25  DecisionTreeRegressor                    HPDD
# 4   DecisionTreeRegressor                    CDIS
# 10  DecisionTreeRegressor                     FDI
# 3   DecisionTreeRegressor                    CDIS
# 20  DecisionTreeRegressor                     FSI
# 0   DecisionTreeRegressor                  BOPAGG
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 19  DecisionTreeRegressor                      FM
# 5   DecisionTreeRegressor                      ED
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 8   DecisionTreeRegressor                     FAS
# 1   DecisionTreeRegressor                    CDIS
# 24  DecisionTreeRegressor                  GENDER
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 6   DecisionTreeRegressor                      ED
# 2   DecisionTreeRegressor                    CDIS
# 18  DecisionTreeRegressor                      FM
# 7   DecisionTreeRegressor                      EQ
# 21  DecisionTreeRegressor                   FSIRE
# 22  DecisionTreeRegressor                   FSIRE
# 12  DecisionTreeRegressor                     FDI
# 17  DecisionTreeRegressor                      FM
#
#                                 column  \
# 9                      FDI_component_0
# 11                     FDI_component_2
# 23                  GENDER_component_0
# 25                    HPDD_component_0
# 4                     CDIS_component_3
# 10                     FDI_component_1
# 3                     CDIS_component_2
# 20                     FSI_component_0
# 0                   BOPAGG_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 13  FISCALDECENTRALIZATION_component_0
# 19                      FM_component_2
# 5                       ED_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 8                      FAS_component_0
# 1                     CDIS_component_0
# 24                  GENDER_component_1
# 15  FISCALDECENTRALIZATION_component_2
# 6                       ED_component_1
# 2                     CDIS_component_1
# 18                      FM_component_1
# 7                       EQ_component_0
# 21                   FSIRE_component_0
# 22                   FSIRE_component_1
# 12                     FDI_component_3
# 17                      FM_component_0
#
#                                          column_descr      mean
# 9                          Financial Development (FD)  0.282535
# 11                         Financial Development (FD)  0.054100
# 23                                             Gender  0.027560
# 25                      Historical Public Debt (HPDD)  0.019000
# 4         Coordinated Direct Investment Survey (CDIS)  0.009371
# 10                         Financial Development (FD)  0.009333
# 3         Coordinated Direct Investment Survey (CDIS)  0.008700
# 20               Financial Soundness Indicators (FSI)  0.008500
# 0                           Balance of Payments (BOP)  0.008325
# 16                            Fiscal Decentralization  0.008255
# 13                            Fiscal Decentralization  0.007720
# 19                                Fiscal Monitor (FM)  0.007015
# 5                         Export Diversification (ED)  0.006580
# 14                            Fiscal Decentralization  0.005625
# 8                       Financial Access Survey (FAS)  0.005344
# 1         Coordinated Direct Investment Survey (CDIS)  0.005267
# 24                                             Gender  0.004983
# 15                            Fiscal Decentralization  0.004713
# 6                         Export Diversification (ED)  0.004600
# 2         Coordinated Direct Investment Survey (CDIS)  0.004162
# 18                                Fiscal Monitor (FM)  0.003720
# 7                                 Export Quality (EQ)  0.003660
# 21  Financial Soundness Indicators Reporting Entit...  0.002940
# 22  Financial Soundness Indicators Reporting Entit...  0.002750
# 12                         Financial Development (FD)  0.002458
# 17                                Fiscal Monitor (FM)  0.001940
# Country Name
# Afghanistan             502.107300
# Albania                5976.555462
# Algeria                3681.617500
# Andorra               38269.115000
# Angola                 2292.356100
#                           ...
# Vietnam                7619.534500
# West Bank and Gaza     7676.579662
# Yemen                  1528.294650
# Zambia                 2840.339533
# Zimbabwe               2392.012800
# Length: 196, dtype: float64

# %% [markdown]
# Calculating Variance Inflation Factor for each principal component within each folter/metric topic.
#
# The second data set filters for VIF < 5

# %%
end_time = time.perf_counter()
print('Process time: ',f"{end_time-start_time:0.4f} seconds {(end_time-start_time)/60:0.4f} minutes.")

vif = pd.DataFrame()
vif['feature_code'] = pca_train_df.columns
vif['VIF'] = [round(variance_inflation_factor(pca_train_df, i),4) for i in range(pca_train_df.shape[1])]
vif['feature_name'] = [meta_dict[x.split('_')[0]] for x in vif['feature_code'] ]
vif= vif.sort_values(by=['VIF'])
vif_all = vif.copy()
print(meta_dict)
print(vif_all)

print(vif_all)
print(vif_all.shape)

vif= vif[vif['VIF'] != np.inf]
vif= vif[vif['VIF'] < 5]
vif = vif.sort_values(by=['VIF'], ascending=False).round(4)

vif['model'] = 'vif'

print(vif)
print(vif.shape)
# Out:
# Process time:  2699.7648 seconds 44.9961 minutes.
# {'BOPAGG': 'Balance of Payments (BOP)', 'ED': 'Export Diversification (ED)', 'EQ': 'Export Quality (EQ)', 'FSI': 'Financial Soundness Indicators (FSI)', 'FSIRE': 'Financial Soundness Indicators Reporting Entities (FSI)', 'GFSCOFOG': 'Government Financial Statistics Expenditure by Function of Government (GFSCOFOG)', 'GFSE': 'Government Financial Statistics Expense (GFSE)', 'GFSFALCS': 'Government Financial Statistics Financial Assets and Liabilities Counterpart (GFSFALCS)', 'GFSIBS': 'Government Financial Statistics Integrated Balance Sheet (GFSIBS)', 'GFSMAB': 'Government Financial Statistics Main Aggregates and Balances (GFSMAB)', 'GFSR': 'Government Financial Statistics Revenue (GFSR)', 'GFSSSUC': 'Government Financial Statistics Statement of Sources and Uses of Cash (GFSSSUC)', 'CDIS': 'Coordinated Direct Investment Survey (CDIS)', 'FAS': 'Financial Access Survey (FAS)', 'FDI': 'Financial Development (FD)', 'FISCALDECENTRALIZATION': 'Fiscal Decentralization', 'FM': 'Fiscal Monitor (FM)', 'GENDER': 'Gender', 'HPDD': 'Historical Public Debt (HPDD)'}
#                           feature_code           VIF  \
# 92  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 66  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 40  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 14  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 91  FISCALDECENTRALIZATION_component_0  1.010600e+00
# ..                                 ...           ...
# 47                   FSIRE_component_0  1.112123e+11
# 54                    CDIS_component_1  4.012294e+11
# 46                     FSI_component_0  1.251000e+12
# 20                     FSI_component_0  1.954687e+12
# 98                     FSI_component_0           inf
#
#                                          feature_name
# 92                            Fiscal Decentralization
# 66                            Fiscal Decentralization
# 40                            Fiscal Decentralization
# 14                            Fiscal Decentralization
# 91                            Fiscal Decentralization
# ..                                                ...
# 47  Financial Soundness Indicators Reporting Entit...
# 54        Coordinated Direct Investment Survey (CDIS)
# 46               Financial Soundness Indicators (FSI)
# 20               Financial Soundness Indicators (FSI)
# 98               Financial Soundness Indicators (FSI)
#
# [104 rows x 3 columns]
#                           feature_code           VIF  \
# 92  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 66  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 40  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 14  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 91  FISCALDECENTRALIZATION_component_0  1.010600e+00
# ..                                 ...           ...
# 47                   FSIRE_component_0  1.112123e+11
# 54                    CDIS_component_1  4.012294e+11
# 46                     FSI_component_0  1.251000e+12
# 20                     FSI_component_0  1.954687e+12
# 98                     FSI_component_0           inf
#
#                                          feature_name
# 92                            Fiscal Decentralization
# 66                            Fiscal Decentralization
# 40                            Fiscal Decentralization
# 14                            Fiscal Decentralization
# 91                            Fiscal Decentralization
# ..                                                ...
# 47  Financial Soundness Indicators Reporting Entit...
# 54        Coordinated Direct Investment Survey (CDIS)
# 46               Financial Soundness Indicators (FSI)
# 20               Financial Soundness Indicators (FSI)
# 98               Financial Soundness Indicators (FSI)
#
# [104 rows x 3 columns]
# (104, 3)
#                           feature_code     VIF                feature_name  \
# 15  FISCALDECENTRALIZATION_component_2  2.7521     Fiscal Decentralization
# 67  FISCALDECENTRALIZATION_component_2  2.7521     Fiscal Decentralization
# 41  FISCALDECENTRALIZATION_component_2  2.7520     Fiscal Decentralization
# 93  FISCALDECENTRALIZATION_component_2  2.7501     Fiscal Decentralization
# 9                      FDI_component_0  2.2877  Financial Development (FD)
# ..                                 ...     ...                         ...
# 91  FISCALDECENTRALIZATION_component_0  1.0106     Fiscal Decentralization
# 40  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
# 66  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
# 14  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
# 92  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
#
#    model
# 15   vif
# 67   vif
# 41   vif
# 93   vif
# 9    vif
# ..   ...
# 91   vif
# 40   vif
# 66   vif
# 14   vif
# 92   vif
#
# [64 rows x 4 columns]
# (64, 4)
# /Users/stephenontko/opt/anaconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# Correlation heat map of principal component analysis components comparing each data sets' average principal component correlation.

# %%
corr_df = pd.DataFrame(abs(pca_train_df.corr()), index = pca_train_df.columns, columns = pca_train_df.columns)
corrMatrix = corr_df.reset_index().melt('index')
corrMatrix.columns = ['var1', 'var2', 'correlation']
corrMatrix.sort_values(by=['correlation'],ascending=True,inplace=True)
corrMatrix['model'] = 'correlation matrix'
corrMatrix['var1_feature_names'] = [meta_dict[x.split('_')[0]] for x in corrMatrix['var1']]
corrMatrix['var2_feature_names'] = [meta_dict[x.split('_')[0]] for x in corrMatrix['var2']]

corrMatrix_heatmap = corrMatrix[:5000]

alt.Chart(corrMatrix_heatmap, title = ["Feature Correlation Heatmap of PCA Features: "
                    ,'Number of Principal Components: '+str(corr_df.shape[0]) 
                    ,'PCA Confidence Interval: '+ str(ci)]
                    ).mark_rect().encode(
    x='var2:O',
    y='var1:O'
    ,color='correlation:Q'
    , tooltip=['correlation:Q','var2_feature_names:O','var1_feature_names:O'],
    ).properties(height=750, width = 900)#.show()

corrMatrix_fileavg=corrMatrix
corrMatrix_fileavg['var1'] = [x.split('_')[0] for x in corrMatrix_fileavg['var1']]
corrMatrix_fileavg['var2'] = [x.split('_')[0] for x in corrMatrix_fileavg['var2']]
corrMatrix_fileavg['var1_feature_names'] = [meta_dict[x.split('_')[0]] for x in corrMatrix_fileavg['var1']]
corrMatrix_fileavg['var2_feature_names'] = [meta_dict[x.split('_')[0]] for x in corrMatrix_fileavg['var2']]

corrMatrix_fileavg=corrMatrix_fileavg.groupby(['var1','var2','var1_feature_names','var2_feature_names','model'],as_index=False)['correlation'].aggregate(['mean']).reset_index().sort_values(by=['mean'], ascending=True)
corrMatrix_fileavg = corrMatrix_fileavg.reset_index()
corrMatrix_fileavg.loc[corrMatrix_fileavg.var1 == corrMatrix_fileavg.var2, 'mean'] = 1
print(corrMatrix_fileavg)


alt.Chart(corrMatrix_fileavg, title = ["Feature Correlation Heatmap of PCA Data Files: "
                    ,'PCA Confidence Interval: '+ str(ci)]
                    ).mark_rect().encode(
    x='var2:O',
    y='var1:O'
    ,color='mean:Q'
    , tooltip=['mean:Q','var2_feature_names:O','var1_feature_names:O'],
    ).properties(height=700, width = 700)#.show()
# Out:
#      index    var1    var2                                 var1_feature_names  \
# 0       20    CDIS     FSI        Coordinated Direct Investment Survey (CDIS)
# 1       97     FSI    CDIS               Financial Soundness Indicators (FSI)
# 2       21    CDIS   FSIRE        Coordinated Direct Investment Survey (CDIS)
# 3      109   FSIRE    CDIS  Financial Soundness Indicators Reporting Entit...
# 4       49     FAS    CDIS                      Financial Access Survey (FAS)
# ..     ...     ...     ...                                                ...
# 139      0  BOPAGG  BOPAGG                          Balance of Payments (BOP)
# 140     52     FAS     FAS                      Financial Access Survey (FAS)
# 141     39      EQ      EQ                                Export Quality (EQ)
# 142    104     FSI     FSI               Financial Soundness Indicators (FSI)
# 143    143    HPDD    HPDD                      Historical Public Debt (HPDD)
#
#                                     var2_feature_names               model  \
# 0                 Financial Soundness Indicators (FSI)  correlation matrix
# 1          Coordinated Direct Investment Survey (CDIS)  correlation matrix
# 2    Financial Soundness Indicators Reporting Entit...  correlation matrix
# 3          Coordinated Direct Investment Survey (CDIS)  correlation matrix
# 4          Coordinated Direct Investment Survey (CDIS)  correlation matrix
# ..                                                 ...                 ...
# 139                          Balance of Payments (BOP)  correlation matrix
# 140                      Financial Access Survey (FAS)  correlation matrix
# 141                                Export Quality (EQ)  correlation matrix
# 142               Financial Soundness Indicators (FSI)  correlation matrix
# 143                      Historical Public Debt (HPDD)  correlation matrix
#
#          mean
# 0    0.006482
# 1    0.006482
# 2    0.009929
# 3    0.009929
# 4    0.011479
# ..        ...
# 139  1.000000
# 140  1.000000
# 141  1.000000
# 142  1.000000
# 143  1.000000
#
# [144 rows x 7 columns]
# Empty DataFrame
# Columns: [model, filename, column, avg_column_significance, column_descr]
# Index: []
# Empty DataFrame
# Columns: [model, max_features, max_depth, ccp_alpha, avg_r_score, avg_rmse]
# Index: []
# Empty DataFrame
# Columns: []
# Index: [Afghanistan, Albania, Algeria, Andorra, Angola, Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, The, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, Brazil, Brunei Darussalam, Bulgaria, Burkina Faso, Burma, Burundi, Cabo Verde, Cambodia, Cameroon, Canada, Central African Republic, Chad, Chile, China, People's Republic of, Colombia, Comoros, Congo, Dem. Rep. of the, Congo, Republic of , Costa Rica, Croatia, Cyprus, Czech Republic, Côte d'Ivoire, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Eswatini, Ethiopia, Fiji, Finland, France, Gabon, Gambia, The, Georgia, Germany, Ghana, Greece, Grenada, Guatemala, Guinea, Guinea-Bissau, Guyana, Haiti, Honduras, Hong Kong SAR, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Israel, Italy, Jamaica, Japan, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Republic of, Kosovo, Kuwait, Kyrgyz Republic, Lao P.D.R., Latvia, Lebanon, Lesotho, Liberia, ...]
#
# [196 rows x 0 columns]
# alt.Chart(...)

# %% [markdown]
# Performing K10Fold on Decision Tree model which is only fitted with principal components from all data set folder/metric topics that have a VIF score of < 5.
#
# Results are included averaged across K10Fold with model R, RMSE scores, mean feature significance, and mean country GDP Per Capita predictions.

# %%
model_score_results = pd.DataFrame()
col_score_results = pd.DataFrame()
model_predictions = pd.DataFrame()
predictions_avg = pd.DataFrame()

print('all pca vif filtered kfold split process: ')
for i, (train_index, test_index) in enumerate(kf10.split(train_X)):
        # print(f"Fold {i}:")
    code_names = pca_train_df.columns
    max_features = 'auto'
    max_depth = 15
    ccp_alpha = .75 #float when increasing from 0 to 1, tree is pruned more to better generalize

    percent_threshold = 0.0009

    # max_features = 'sqrt'
    max_depth = 25
    ccp_alpha = .9 #float when increasing from 0 to 1, tree is pruned more to better generalize

    # print([pca_train_df.columns.index(x) for x in vif['feature_code']])
    dt_regr = DecisionTreeRegressor(max_features= max_features, max_depth= max_depth, ccp_alpha = ccp_alpha).fit(pd.DataFrame(pca_train_df).iloc[train_index,[x for x in vif.index]], pd.DataFrame(train_y_df).iloc[train_index,:])
    dt_regr_score = dt_regr.score(pd.DataFrame(pca_train_df).iloc[test_index,[x for x in vif.index]], pd.DataFrame(train_y_df).iloc[test_index,:])
    dt_regr_predict = dt_regr.predict(pd.DataFrame(pca_test_df).iloc[:,[x for x in vif.index]])

    rmse = round(math.sqrt(mean_squared_error(train_y_df, dt_regr_predict)),3)

    dt_col_results = pd.DataFrame(columns = ['model','filename', 'max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
    # print(dt_regr.feature_importances_)
    print([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]])
    for sig_i, sig_column in enumerate([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]]):

        col_score = round([dt_regr.feature_importances_[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]][sig_i],4)
        col_df = pd.DataFrame([[dt_regr.__class__.__name__, sig_column.split('_')[0]
                                , max_features, max_depth, ccp_alpha, dt_regr_score, rmse ,sig_column, col_score
                                ,meta_dict[sig_column.split('_')[0]]
                               ]]
                               ,columns = ['model','filename', 'max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
        dt_col_results = pd.concat([dt_col_results, col_df], axis = 0)

    model_score_results = pd.concat([model_score_results,dt_col_results[['model','max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse']].drop_duplicates()],axis=0)
    col_score_results = pd.concat([col_score_results,dt_col_results[['model','filename','column','avg_column_significance', 'column_descr']]],axis=0)

    model_predictions = pd.DataFrame(dt_regr_predict, index=test_y_df.index)
    predictions_avg = pd.concat([predictions_avg, model_predictions],axis=1)

model_score_results=model_score_results.groupby(['model','max_features','max_depth','ccp_alpha'],as_index = False).mean().reset_index()
col_score_results=col_score_results.groupby(['model','filename','column', 'column_descr'],as_index = False)['avg_column_significance'].aggregate(['mean']).reset_index().sort_values(by=['mean'], ascending=False)
print(nca_pca.get_params(deep=True))
print(model_score_results)
# print(col_score_results)
print(col_score_results[['column','column_descr','mean']])
print(col_score_results[['column','column_descr','mean']].shape)
# print(col_score_results.columns)
# Out:
# all pca vif filtered kfold split process:
# ['CDIS_component_1', 'CDIS_component_2', 'CDIS_component_3', 'ED_component_0', 'EQ_component_0', 'FDI_component_1', 'FDI_component_2', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_2', 'FM_component_0', 'FSIRE_component_0', 'GENDER_component_0', 'GENDER_component_1', 'CDIS_component_2', 'ED_component_0', 'ED_component_1', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_1', 'FM_component_0', 'FM_component_1', 'FSIRE_component_0', 'BOPAGG_component_0', 'EQ_component_0', 'FAS_component_0']
# ['BOPAGG_component_0', 'CDIS_component_3', 'ED_component_0', 'ED_component_1', 'FDI_component_0', 'FDI_component_1', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_1', 'FM_component_2', 'FSIRE_component_0', 'FSIRE_component_1', 'CDIS_component_0', 'CDIS_component_1', 'ED_component_0', 'EQ_component_0', 'FDI_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_1', 'FM_component_1', 'FSI_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'GENDER_component_1', 'CDIS_component_1', 'CDIS_component_3']
# ['CDIS_component_1', 'CDIS_component_3', 'ED_component_0', 'ED_component_1', 'FAS_component_0', 'FDI_component_2', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_1', 'FM_component_2', 'FSIRE_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'ED_component_1', 'FAS_component_0', 'FDI_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_1', 'FM_component_2', 'FSI_component_0', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_2', 'FDI_component_0']
# ['CDIS_component_0', 'CDIS_component_2', 'CDIS_component_3', 'ED_component_0', 'ED_component_1', 'EQ_component_0', 'FAS_component_0', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_1', 'FM_component_0', 'FM_component_1', 'FSIRE_component_0', 'BOPAGG_component_0', 'CDIS_component_2', 'ED_component_0', 'FAS_component_0', 'FSIRE_component_0', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'BOPAGG_component_0', 'CDIS_component_0', 'CDIS_component_2', 'FDI_component_0']
# ['BOPAGG_component_0', 'CDIS_component_0', 'CDIS_component_3', 'ED_component_0', 'EQ_component_0', 'FAS_component_0', 'FDI_component_2', 'FDI_component_3', 'FM_component_0', 'FM_component_1', 'FSI_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'BOPAGG_component_0', 'CDIS_component_1', 'CDIS_component_2', 'FAS_component_0', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_1', 'FM_component_2', 'FSIRE_component_0', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_2']
# ['BOPAGG_component_0', 'CDIS_component_2', 'CDIS_component_3', 'ED_component_1', 'EQ_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_2', 'FSI_component_0', 'GENDER_component_0', 'GENDER_component_1', 'CDIS_component_2', 'CDIS_component_3', 'ED_component_1', 'EQ_component_0', 'FAS_component_0', 'FDI_component_0', 'FDI_component_3', 'FM_component_2', 'FSI_component_0', 'FSIRE_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'BOPAGG_component_0', 'CDIS_component_1', 'CDIS_component_2', 'FAS_component_0']
# ['CDIS_component_1', 'CDIS_component_3', 'ED_component_1', 'EQ_component_0', 'FAS_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_2', 'FM_component_1', 'FSI_component_0', 'FSIRE_component_0', 'CDIS_component_2', 'ED_component_0', 'EQ_component_0', 'FAS_component_0', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_1', 'FSI_component_0', 'FSIRE_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'HPDD_component_0', 'CDIS_component_0', 'CDIS_component_3', 'ED_component_0']
# ['CDIS_component_1', 'ED_component_0', 'ED_component_1', 'EQ_component_0', 'FDI_component_0', 'FDI_component_1', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_2', 'FSI_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'GENDER_component_1', 'BOPAGG_component_0', 'ED_component_0', 'FAS_component_0', 'FDI_component_0', 'FDI_component_2', 'FDI_component_3', 'FSI_component_0', 'FSIRE_component_0', 'FSIRE_component_1', 'GENDER_component_0', 'BOPAGG_component_0', 'CDIS_component_2', 'EQ_component_0', 'FDI_component_2']
# ['CDIS_component_0', 'CDIS_component_2', 'ED_component_1', 'EQ_component_0', 'FDI_component_1', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_2', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_1', 'FSI_component_0', 'FSIRE_component_0', 'GENDER_component_0', 'GENDER_component_1', 'CDIS_component_1', 'CDIS_component_3', 'ED_component_0', 'ED_component_1', 'EQ_component_0', 'FDI_component_0', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_1', 'FM_component_2', 'FSI_component_0', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'CDIS_component_0', 'FDI_component_1']
# ['BOPAGG_component_0', 'CDIS_component_1', 'CDIS_component_2', 'CDIS_component_3', 'EQ_component_0', 'FISCALDECENTRALIZATION_component_0', 'FISCALDECENTRALIZATION_component_3', 'FM_component_0', 'FM_component_2', 'FSI_component_0', 'FSIRE_component_1', 'HPDD_component_0', 'BOPAGG_component_0', 'CDIS_component_1', 'CDIS_component_2', 'ED_component_0', 'ED_component_1', 'FAS_component_0', 'FDI_component_3', 'FISCALDECENTRALIZATION_component_1', 'FISCALDECENTRALIZATION_component_2', 'FM_component_2', 'GENDER_component_0', 'GENDER_component_1', 'HPDD_component_0', 'FDI_component_0']
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
#    index                  model max_features  max_depth  ccp_alpha  \
# 0      0  DecisionTreeRegressor         auto         25        0.9
#
#    avg_r_score   avg_rmse
# 0     0.420188  5183.6436
#                                 column  \
# 5                       ED_component_0
# 4                     CDIS_component_3
# 7                       EQ_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 17                      FM_component_0
# 22                   FSIRE_component_1
# 18                      FM_component_1
# 21                   FSIRE_component_0
# 24                  GENDER_component_1
# 6                       ED_component_1
# 23                  GENDER_component_0
# 25                    HPDD_component_0
# 20                     FSI_component_0
# 8                      FAS_component_0
# 12                     FDI_component_3
# 15  FISCALDECENTRALIZATION_component_2
# 19                      FM_component_2
# 9                      FDI_component_0
# 2                     CDIS_component_1
# 1                     CDIS_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 3                     CDIS_component_2
# 11                     FDI_component_2
# 10                     FDI_component_1
# 0                   BOPAGG_component_0
# 14  FISCALDECENTRALIZATION_component_1
#
#                                          column_descr      mean
# 5                         Export Diversification (ED)  0.175943
# 4         Coordinated Direct Investment Survey (CDIS)  0.165058
# 7                                 Export Quality (EQ)  0.141629
# 16                            Fiscal Decentralization  0.043880
# 17                                Fiscal Monitor (FM)  0.038154
# 22  Financial Soundness Indicators Reporting Entit...  0.031611
# 18                                Fiscal Monitor (FM)  0.026142
# 21  Financial Soundness Indicators Reporting Entit...  0.023750
# 24                                             Gender  0.019070
# 6                         Export Diversification (ED)  0.016792
# 23                                             Gender  0.014940
# 25                      Historical Public Debt (HPDD)  0.012186
# 20               Financial Soundness Indicators (FSI)  0.010933
# 8                       Financial Access Survey (FAS)  0.009938
# 12                         Financial Development (FD)  0.009936
# 15                            Fiscal Decentralization  0.009650
# 19                                Fiscal Monitor (FM)  0.008970
# 9                          Financial Development (FD)  0.007700
# 2         Coordinated Direct Investment Survey (CDIS)  0.007455
# 1         Coordinated Direct Investment Survey (CDIS)  0.006657
# 13                            Fiscal Decentralization  0.006129
# 3         Coordinated Direct Investment Survey (CDIS)  0.004981
# 11                         Financial Development (FD)  0.004433
# 10                         Financial Development (FD)  0.003640
# 0                           Balance of Payments (BOP)  0.003525
# 14                            Fiscal Decentralization  0.002967
# (26, 3)

# %% [markdown]
# Averaged Column significance scores after vif < 5 pca decision tree model fit. Mean column significance and VIF scores provided.

# %%
print(col_score_results)
print(col_score_results.columns)
# print(col_score_results['column'])
# print([x for x in col_score_results['column']])
print(vif)
col_score_results['vif'] = [list(vif_all[vif_all['feature_code']==x]['VIF'].unique())[0] for x in col_score_results['column']]
print(col_score_results)
# Out:
#                     model                filename  \
# 5   DecisionTreeRegressor                      ED
# 4   DecisionTreeRegressor                    CDIS
# 7   DecisionTreeRegressor                      EQ
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 17  DecisionTreeRegressor                      FM
# 22  DecisionTreeRegressor                   FSIRE
# 18  DecisionTreeRegressor                      FM
# 21  DecisionTreeRegressor                   FSIRE
# 24  DecisionTreeRegressor                  GENDER
# 6   DecisionTreeRegressor                      ED
# 23  DecisionTreeRegressor                  GENDER
# 25  DecisionTreeRegressor                    HPDD
# 20  DecisionTreeRegressor                     FSI
# 8   DecisionTreeRegressor                     FAS
# 12  DecisionTreeRegressor                     FDI
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 19  DecisionTreeRegressor                      FM
# 9   DecisionTreeRegressor                     FDI
# 2   DecisionTreeRegressor                    CDIS
# 1   DecisionTreeRegressor                    CDIS
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 3   DecisionTreeRegressor                    CDIS
# 11  DecisionTreeRegressor                     FDI
# 10  DecisionTreeRegressor                     FDI
# 0   DecisionTreeRegressor                  BOPAGG
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION
#
#                                 column  \
# 5                       ED_component_0
# 4                     CDIS_component_3
# 7                       EQ_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 17                      FM_component_0
# 22                   FSIRE_component_1
# 18                      FM_component_1
# 21                   FSIRE_component_0
# 24                  GENDER_component_1
# 6                       ED_component_1
# 23                  GENDER_component_0
# 25                    HPDD_component_0
# 20                     FSI_component_0
# 8                      FAS_component_0
# 12                     FDI_component_3
# 15  FISCALDECENTRALIZATION_component_2
# 19                      FM_component_2
# 9                      FDI_component_0
# 2                     CDIS_component_1
# 1                     CDIS_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 3                     CDIS_component_2
# 11                     FDI_component_2
# 10                     FDI_component_1
# 0                   BOPAGG_component_0
# 14  FISCALDECENTRALIZATION_component_1
#
#                                          column_descr      mean  \
# 5                         Export Diversification (ED)  0.175943
# 4         Coordinated Direct Investment Survey (CDIS)  0.165058
# 7                                 Export Quality (EQ)  0.141629
# 16                            Fiscal Decentralization  0.043880
# 17                                Fiscal Monitor (FM)  0.038154
# 22  Financial Soundness Indicators Reporting Entit...  0.031611
# 18                                Fiscal Monitor (FM)  0.026142
# 21  Financial Soundness Indicators Reporting Entit...  0.023750
# 24                                             Gender  0.019070
# 6                         Export Diversification (ED)  0.016792
# 23                                             Gender  0.014940
# 25                      Historical Public Debt (HPDD)  0.012186
# 20               Financial Soundness Indicators (FSI)  0.010933
# 8                       Financial Access Survey (FAS)  0.009938
# 12                         Financial Development (FD)  0.009936
# 15                            Fiscal Decentralization  0.009650
# 19                                Fiscal Monitor (FM)  0.008970
# 9                          Financial Development (FD)  0.007700
# 2         Coordinated Direct Investment Survey (CDIS)  0.007455
# 1         Coordinated Direct Investment Survey (CDIS)  0.006657
# 13                            Fiscal Decentralization  0.006129
# 3         Coordinated Direct Investment Survey (CDIS)  0.004981
# 11                         Financial Development (FD)  0.004433
# 10                         Financial Development (FD)  0.003640
# 0                           Balance of Payments (BOP)  0.003525
# 14                            Fiscal Decentralization  0.002967
#
#                          vif
# 5           [1.1599, 1.1598]
# 4                         []
# 7                         []
# 16           [1.566, 1.5605]
# 17          [1.0756, 1.0755]
# 22                        []
# 18          [1.0622, 1.0621]
# 21                        []
# 24                  [1.0196]
# 6   [1.0455, 1.0452, 1.0449]
# 23                  [1.1637]
# 25                  [1.0451]
# 20                        []
# 8                         []
# 12                  [1.0466]
# 15   [2.7521, 2.752, 2.7501]
# 19          [1.0756, 1.0755]
# 9   [2.2877, 2.2871, 2.2864]
# 2                         []
# 1                         []
# 13                  [1.0106]
# 3                         []
# 11   [1.168, 1.1679, 1.1678]
# 10   [1.1931, 1.193, 1.1929]
# 0                         []
# 14                  [1.0081]
# Index(['model', 'filename', 'column', 'column_descr', 'mean', 'vif'], dtype='object')
#                           feature_code     VIF                feature_name  \
# 15  FISCALDECENTRALIZATION_component_2  2.7521     Fiscal Decentralization
# 67  FISCALDECENTRALIZATION_component_2  2.7521     Fiscal Decentralization
# 41  FISCALDECENTRALIZATION_component_2  2.7520     Fiscal Decentralization
# 93  FISCALDECENTRALIZATION_component_2  2.7501     Fiscal Decentralization
# 9                      FDI_component_0  2.2877  Financial Development (FD)
# ..                                 ...     ...                         ...
# 91  FISCALDECENTRALIZATION_component_0  1.0106     Fiscal Decentralization
# 40  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
# 66  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
# 14  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
# 92  FISCALDECENTRALIZATION_component_1  1.0081     Fiscal Decentralization
#
#    model
# 15   vif
# 67   vif
# 41   vif
# 93   vif
# 9    vif
# ..   ...
# 91   vif
# 40   vif
# 66   vif
# 14   vif
# 92   vif
#
# [64 rows x 4 columns]
#                     model                filename  \
# 5   DecisionTreeRegressor                      ED
# 4   DecisionTreeRegressor                    CDIS
# 7   DecisionTreeRegressor                      EQ
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 17  DecisionTreeRegressor                      FM
# 22  DecisionTreeRegressor                   FSIRE
# 18  DecisionTreeRegressor                      FM
# 21  DecisionTreeRegressor                   FSIRE
# 24  DecisionTreeRegressor                  GENDER
# 6   DecisionTreeRegressor                      ED
# 23  DecisionTreeRegressor                  GENDER
# 25  DecisionTreeRegressor                    HPDD
# 20  DecisionTreeRegressor                     FSI
# 8   DecisionTreeRegressor                     FAS
# 12  DecisionTreeRegressor                     FDI
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 19  DecisionTreeRegressor                      FM
# 9   DecisionTreeRegressor                     FDI
# 2   DecisionTreeRegressor                    CDIS
# 1   DecisionTreeRegressor                    CDIS
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION
# 3   DecisionTreeRegressor                    CDIS
# 11  DecisionTreeRegressor                     FDI
# 10  DecisionTreeRegressor                     FDI
# 0   DecisionTreeRegressor                  BOPAGG
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION
#
#                                 column  \
# 5                       ED_component_0
# 4                     CDIS_component_3
# 7                       EQ_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 17                      FM_component_0
# 22                   FSIRE_component_1
# 18                      FM_component_1
# 21                   FSIRE_component_0
# 24                  GENDER_component_1
# 6                       ED_component_1
# 23                  GENDER_component_0
# 25                    HPDD_component_0
# 20                     FSI_component_0
# 8                      FAS_component_0
# 12                     FDI_component_3
# 15  FISCALDECENTRALIZATION_component_2
# 19                      FM_component_2
# 9                      FDI_component_0
# 2                     CDIS_component_1
# 1                     CDIS_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 3                     CDIS_component_2
# 11                     FDI_component_2
# 10                     FDI_component_1
# 0                   BOPAGG_component_0
# 14  FISCALDECENTRALIZATION_component_1
#
#                                          column_descr      mean           vif
# 5                         Export Diversification (ED)  0.175943  1.159800e+00
# 4         Coordinated Direct Investment Survey (CDIS)  0.165058  4.745166e+06
# 7                                 Export Quality (EQ)  0.141629  2.047621e+03
# 16                            Fiscal Decentralization  0.043880  1.560500e+00
# 17                                Fiscal Monitor (FM)  0.038154  1.075500e+00
# 22  Financial Soundness Indicators Reporting Entit...  0.031611  1.237752e+09
# 18                                Fiscal Monitor (FM)  0.026142  1.062100e+00
# 21  Financial Soundness Indicators Reporting Entit...  0.023750  3.669233e+09
# 24                                             Gender  0.019070  1.019600e+00
# 6                         Export Diversification (ED)  0.016792  1.044900e+00
# 23                                             Gender  0.014940  1.163700e+00
# 25                      Historical Public Debt (HPDD)  0.012186  1.045100e+00
# 20               Financial Soundness Indicators (FSI)  0.010933  6.763741e+09
# 8                       Financial Access Survey (FAS)  0.009938  1.026327e+09
# 12                         Financial Development (FD)  0.009936  1.046600e+00
# 15                            Fiscal Decentralization  0.009650  2.750100e+00
# 19                                Fiscal Monitor (FM)  0.008970  1.075500e+00
# 9                          Financial Development (FD)  0.007700  2.286400e+00
# 2         Coordinated Direct Investment Survey (CDIS)  0.007455  7.733078e+07
# 1         Coordinated Direct Investment Survey (CDIS)  0.006657  6.978410e+07
# 13                            Fiscal Decentralization  0.006129  1.010600e+00
# 3         Coordinated Direct Investment Survey (CDIS)  0.004981  2.224804e+06
# 11                         Financial Development (FD)  0.004433  1.167800e+00
# 10                         Financial Development (FD)  0.003640  1.192900e+00
# 0                           Balance of Payments (BOP)  0.003525  5.128073e+07
# 14                            Fiscal Decentralization  0.002967  1.008100e+00

# %% [markdown]
# Failure analysis of performing K10Fold on Decision Tree model which is only fitted with principal components from all data set folder/metric topics that have a VIF score of < 5.
# Results are included averaged across K10Fold with model R, RMSE scores, mean feature significance, and mean country GDP Per Capita predictions.
# Falure analysis is then performed, finding the percentage difference of predicted GDP per capita across all counties' actual GDP Per capita for the target year of the predictions.

# %%
#for failure analysis:
prediction_eval = pd.DataFrame(test_y_df,columns=[train_year+2],index = test_y_df.index)
prediction_eval = pd.concat([prediction_eval,pd.DataFrame(predictions_avg.mean(axis=1),columns=['avg_prediction'])],axis=1)
prediction_eval = pd.concat([prediction_eval,pd.DataFrame(predictions_avg.std(axis=1),columns=['std_avg_prediction'])],axis=1).astype(float)
prediction_eval = prediction_eval.replace(0,np.nan)
prediction_eval['prediction_difference_percent'] = ((prediction_eval[train_year+2] - prediction_eval['avg_prediction'])/prediction_eval[train_year+2])*-100
prediction_eval['prediction_difference_percent_abs'] = abs(prediction_eval['prediction_difference_percent'])
prediction_eval=prediction_eval.sort_values(by=['prediction_difference_percent_abs'],ascending=False)
prediction_eval['GDP Per Capita'] = prediction_eval[train_year+2]
prediction_eval['Country Name'] = prediction_eval.index
prediction_eval.drop(columns=[train_year+2],inplace=True)
# prediction_eval = prediction_eval[prediction_eval['prediction_difference_percent_abs']<100]

forecast_failure_chart = alt.Chart(prediction_eval.iloc[:30, :]
                                   , title = ["Countries with the Greatest Forecast Discrepancies:"
                    ,'Forecast Year: ' + str(train_year +2) 
                    ,'Model: '+model_score_results['model'][0]+ ' Score: '+str(round(model_score_results['avg_r_score'][0],4))
                    +' RMSE: '+str(round(model_score_results['avg_rmse'][0],4))]
                    
                    ).mark_geoshape(stroke='black' 
                                    ,fillOpacity=1,strokeWidth=.05
                                   ).mark_bar().encode( 
    x = alt.X('prediction_difference_percent:Q',scale = alt.Scale(domain=[prediction_eval['prediction_difference_percent'][:30].min(),
                                                             prediction_eval['prediction_difference_percent'][:30].max()])),  
    y=alt.Y("Country Name:O", sort=alt.SortField("prediction_difference_percent_abs", order="descending"))
    , tooltip=['GDP Per Capita:Q', 'prediction_difference_percent:Q'],
    color=alt.Color('GDP Per Capita:Q', scale= alt.Scale(range=['darkred','darkblue']
                                                         ,domain=[prediction_eval['GDP Per Capita'][:30].min(),#
                                                             prediction_eval['GDP Per Capita'][:30].max()]#
                                                          ))
    ).properties(height=800, width = 900)

forecast_failure_chart#.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# Choropleth Map of Failure Analysis of Decision Tree fitted with PCAs of VIF < 5.
# Compares percentage difference of actual gdp per capita and predicted gdp per capita for forecast target year for all countries.

# %%
def chart_diff_compilation(choropleth_actual_differences_df, train_year, model, model_score, rmse):


    gdpforecast= alt.Chart(
        world
          , title = ["GDP Per Capita Difference From Actual: "
                    ,'Forecast Year: ' + str(train_year +2) 
                    ,'Model: '+model+ ' Score: '+str(model_score)
                    +' RMSE: '+str(rmse)]
                    ).mark_geoshape(stroke='black' #'white'
                                    ,fillOpacity=1,strokeWidth=.05).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=choropleth_actual_differences_df, key = 'id', fields=['Country Name','id','prediction_difference_percent'])
    ).encode(
    # tooltip='properties.geounit:N',
    color=alt.Color('prediction_difference_percent:Q'
                    ,scale= alt.Scale(
#                         domain=[    choropleth_actual_differences_df['Percent Difference From Actual'].min()
#                                     ,choropleth_actual_differences_df['Percent Difference From Actual'].max()
#                                ],
#                                         choropleth_actual_differences_df['Percent Difference From Actual'].min()
#                                               ,choropleth_actual_differences_df['Percent Difference From Actual'].max()]
                                        # ,range=['red','yellow','green']
#                                         ,
                        range=['darkred','darkblue']
                                      ))
    , tooltip=['Country Name:N', 'prediction_difference_percent:Q']

    ).project(
    type='mercator'
    ).properties(
    width=800,
    height=800
#     width=400,
#     height=400
    )
    gdpforecast#.show()
    return  gdpforecast


prediction_eval['Country Name'] = prediction_eval.index
prediction_eval['id'] = [iso_country_codes[x] for x in prediction_eval.index]

# print(prediction_eval)
# print(prediction_eval.columns)
chart_diff_compilation(prediction_eval, train_year, model_score_results['model'][0], round(model_score_results['avg_r_score'][0],4), round(model_score_results['avg_rmse'][0],4))
# Out:
# alt.Chart(...)

# %% [markdown]
# Parameter turning of K10Fold on Decision Tree model when only fitted with principal components from all data set folder/metric topics that have a VIF score of < 5. Parameter combinations iterate through max feature algorithms, max depths, and alpha values.

# %%
def dt_model_kfold_pca_vif(max_features, max_depth, ccp_alpha ,pca_train_df, train_y_df, pca_test_df, test_y_df, splits):
    param_tune_df = pd.DataFrame(columns = ['max_features','max_depth','alpha','avg_r_score','r_std','avg_rmse_score','rmse_std'])
    kf10 = KFold(n_splits = splits)
    kf10.get_n_splits(pca_train_df)

    k10_fold_r_results = pd.DataFrame(columns = ['r_score','rmse_score'])

    for i, (train_index, test_index) in enumerate(kf10.split(pca_train_df)):
        # print(f"Fold {i}:")
        dt_regr = DecisionTreeRegressor(max_features= max_features, max_depth= max_depth, ccp_alpha = ccp_alpha).fit(pd.DataFrame(pca_train_df).iloc[train_index,[x for x in vif.index]], pd.DataFrame(train_y_df).iloc[train_index,:])
        dt_regr_score = dt_regr.score(pd.DataFrame(pca_train_df).iloc[test_index,[x for x in vif.index]], pd.DataFrame(train_y_df).iloc[test_index,:])
        dt_regr_predict = dt_regr.predict(pd.DataFrame(pca_test_df).iloc[:,[x for x in vif.index]])

        rmse = round(math.sqrt(mean_squared_error(test_y_df, dt_regr_predict)),3)

        k10_fold_r_results = pd.concat([k10_fold_r_results,pd.DataFrame([[dt_regr_score,rmse]],columns = ['r_score','rmse_score'])],axis=0)

        r_mean = k10_fold_r_results['r_score'].mean(axis=0)
        r_std = k10_fold_r_results['r_score'].std(axis=0)
        rmse_mean = k10_fold_r_results['rmse_score'].mean(axis=0)
        rmse_std=k10_fold_r_results['rmse_score'].std(axis=0)
        param_tune_df = pd.concat([param_tune_df, pd.DataFrame([[max_features, max_depth,ccp_alpha,r_mean ,r_std ,rmse_mean ,rmse_std]],columns = ['max_features','max_depth','alpha','avg_r_score','r_std','avg_rmse_score','rmse_std'])],axis=0)
    param_tune_df=param_tune_df.groupby(['max_features','max_depth','alpha'],as_index = False).mean().reset_index()
    return param_tune_df

#parameter tuning
all_max_features = ['log2','auto','sqrt']
max_depths = [5, 10, 15, 20, 25, 30]
alpha_values = [.1, .25, .5, .75, .9]

param_tune_df = pd.DataFrame(columns = ['max_features','max_depth','alpha','avg_r_score','avg_rmse_score'])

for max_feat in all_max_features:
    for max_dep in max_depths:
        for alph in alpha_values: 
            iter_param_tune_df = dt_model_kfold_pca_vif(max_feat, max_dep, alph ,pca_train_df, train_y_df, pca_test_df, test_y_df, 10)
            param_tune_df = pd.concat([param_tune_df,iter_param_tune_df[['max_features','max_depth','alpha','avg_r_score','avg_rmse_score']]],axis=0)
param_tune_df = param_tune_df.sort_values(by=['avg_r_score'], ascending=False)
# param_tune_df.to_csv('/Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/alL_data_sets_pca_decision_tree_param_tuning.csv',index=True)
# param_tune_df = pd.read_csv('/Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/alL_data_sets_pca_decision_tree_param_tuning.csv')
print(param_tune_df.head(20))
# Out:
#   max_features max_depth alpha avg_r_score avg_rmse_score
# 0         auto         5  0.75    0.674494    7263.678818
# 0         auto         5   0.9    0.673691    7189.000166
# 0         auto         5  0.25    0.667414    7250.923894
# 0         auto         5   0.5    0.663563    7195.627539
# 0         auto         5   0.1    0.650816    7173.346791
# 0         sqrt         5   0.5    0.623624    8937.739584
# 0         log2        10   0.5     0.60856    5592.711118
# 0         auto        10   0.1    0.597089    5216.217976
# 0         auto        10   0.5    0.596783    5499.681462
# 0         auto        25   0.5    0.593528    4916.624748
# 0         auto        15   0.9    0.585414    4952.052165
# 0         auto        10   0.9    0.582002    5337.300798
# 0         auto        20   0.1    0.578053    4976.974371
# 0         auto        30  0.25    0.576017    5140.962944
# 0         auto        30   0.9    0.568602    4986.933891
# 0         sqrt        10  0.25    0.566658    5462.250476
# 0         auto        20  0.25    0.565932    5340.190954
# 0         auto        10  0.75    0.565774     5320.25505
# 0         auto        20   0.5    0.559984    5086.023878
# 0         auto        15  0.25    0.557904    4995.586292

# %% [markdown]
# Choropleth maps of, on the top, countries' actual GDP per capita for the target year.
# The bottom graph maps the predicted GDP per capita for each country for the predicted target year using the model trained on PCAs with a VIF < 5. R and RMSE scores are also outputted.

# %%
#choropleth map chart of predictions
def choropleth_dfs(test_y, train_year, predictions):
    choropleth_df = test_y.copy().astype(float)
    choropleth_df['Country Name'] = choropleth_df.index
    choropleth_df['GDP Per Capita'] = [x for x in predictions]
    choropleth_df['id'] = [iso_country_codes[x] for x in choropleth_df.index]

    choropleth_actual_df = choropleth_df[['Country Name',train_year+2,'id']]
    choropleth_actual_df.rename(columns={train_year+2:'GDP Per Capita'},inplace=True)
    choropleth_actual_df = choropleth_actual_df[['Country Name','GDP Per Capita','id']]

    choropleth_df = choropleth_df[['Country Name','GDP Per Capita','id']]
    return choropleth_df, choropleth_actual_df

def chart_compilation(choropleth_df, choropleth_actual_df, train_year, model, model_score,rmse):
    gdpactual= alt.Chart(
        world
          , title = ["Actual GDP Per Capita"
                    ,'for Year: ' + str(train_year +2)]).mark_geoshape(stroke='black' #'white'
                                                                ,fillOpacity=1,strokeWidth=.05).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=choropleth_actual_df, key = 'id', fields=['id','Country Name','GDP Per Capita'])
    ).encode(
    # tooltip='properties.geounit:N',
    color=alt.Color('GDP Per Capita:Q'
                    ,scale= alt.Scale(domain=[
                                                # 0,100000
                                            choropleth_actual_df['GDP Per Capita'].min()
                                              ,choropleth_actual_df['GDP Per Capita'].max()
                                              ]
                                        # ,range=['red','yellow','green']
                                        ,range=['lightgreen','darkblue']
                                      ))
    , tooltip=['Country Name:N', 'GDP Per Capita:Q']

    ).project(
    type='mercator'
    ).properties(
    width=600,
    height=600
    )
    gdpactual#.show()

    gdpforecast= alt.Chart(
        world
          , title = ["GDP Per Capita Forecasting : "
                    ,'Forecast Year: ' + str(train_year +2) 
                    ,'Model: '+model.__class__.__name__+ ' Score: '+str(round(model_score,4))
                    +' RMSE: '+str(rmse)]
                    ).mark_geoshape(stroke='black' #'white'
                                    ,fillOpacity=1,strokeWidth=.05).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=choropleth_df, key = 'id', fields=['id','Country Name','GDP Per Capita'])
    ).encode(
    # tooltip='properties.geounit:N',
    color=alt.Color('GDP Per Capita:Q'
                    ,scale= alt.Scale(domain=[
                                           # 0
                                        choropleth_df['GDP Per Capita'].min()
                                              ,choropleth_df['GDP Per Capita'].max()]
                                        # ,range=['red','yellow','green']
                                        ,range=['lightgreen','darkblue']
                                      ))
    , tooltip=['Country Name:N', 'GDP Per Capita:Q']

    ).project(
    type='mercator'
    ).properties(
    width=600,
    height=600
    )
    gdpforecast#.show()
    return alt.vconcat(gdpactual, gdpforecast)# alt.hconcat(gdpactual, gdpforecast)#.show()

choropleth_df, choropleth_actual_df = choropleth_dfs(test_y_df, train_year, predictions_avg.mean(axis=1))
print(model_score_results.columns)
print(model_score_results['model'][0])
print(model_score_results['avg_r_score'][0])
print(model_score_results['avg_rmse'][0])
chart_compilation(choropleth_df, choropleth_actual_df, train_year, model_score_results['model'][0]
                  , model_score_results['avg_r_score'][0], model_score_results['avg_rmse'][0])
# Out:
# Index(['index', 'model', 'max_features', 'max_depth', 'ccp_alpha',
#        'avg_r_score', 'avg_rmse'],
#       dtype='object')
# DecisionTreeRegressor
# 0.4201883187295257
# 5183.6436
# /var/folders/7l/v039n9y14dl1p58v4l2n14_r0000gn/T/ipykernel_33947/3920954895.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   choropleth_actual_df.rename(columns={train_year+2:'GDP Per Capita'},inplace=True)
# alt.VConcatChart(...)

# %% [markdown]
# Failure analysis of performing K10Fold on Decision Tree model which is only fitted with principal components from all data set folder/metric topics that have a VIF score of < 5

# %%
#learning rate
learning_rates = [25, 50, 75, 100, 125, 150, 175, train_y_df.shape[0]]

learning_rate_df = pd.DataFrame(columns = ['max_features','max_depth','alpha','avg_r_score','avg_rmse_score','samples'])

for learning_rate in learning_rates:
    print(learning_rate)
    random_sample_indices = random.sample(range(0,learning_rate),learning_rate)
    #sqrt, 15, .75
    max_features = 'auto'
    max_depth = 25
    ccp_alpha = .9
    iter_learning_rate_df = dt_model_kfold_pca_vif(max_features, max_depth, ccp_alpha ,pca_train_df.iloc[random_sample_indices,:], train_y_df.iloc[random_sample_indices,:], pca_test_df.iloc[random_sample_indices,:], test_y_df.iloc[random_sample_indices,:], 10)
    iter_learning_rate_df['samples'] = learning_rate
    learning_rate_df = pd.concat([learning_rate_df,iter_learning_rate_df[['max_features','max_depth','alpha','avg_r_score','avg_rmse_score','samples']]],axis=0)
print(learning_rate_df)
# learning_rate_df.to_csv('/Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/alL_data_sets_pca_decision_tree_learning_rate.csv',index=True)
# param_tune_df = pd.read_csv('/Users/stephenontko/Documents/University of Michigan/UMSI/UMSI MADS/UMSI MADS 2023/SIADS 699 Capstone/Data/IMF/alL_data_sets_pca_decision_tree_param_tuning.csv')
# print(param_tune_df)
# Out:
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 196
#   max_features max_depth alpha  avg_r_score avg_rmse_score samples
# 0         auto        25   0.9 -6936.805741    4666.398528      25
# 0         auto        25   0.9     0.042139     4436.91327      50
# 0         auto        25   0.9     0.049534    3947.507281      75
# 0         auto        25   0.9      0.42835    4530.849634     100
# 0         auto        25   0.9     0.230028    5751.574221     125
# 0         auto        25   0.9     0.415512    4855.385168     150
# 0         auto        25   0.9        0.527    5564.798531     175
# 0         auto        25   0.9     0.285974    5780.768498     196

# %% [markdown]
# Iterating through decision tree model fitted with PCA components with VIF score < 5.
#
# Averages of PCA component column significances are take from K10Fold, with the fold iterated 4 times, with the top component/column score returned to see the statbility of the column scores from each model fitting.

# %%
# iter pca
iter_pca_col_score_results =pd.DataFrame(columns = ['model','filename','iteration','column', 'column_descr','avg_column_significance'])

for iter_pca in range(1,5):
    print(iter_pca)
    # model_score_results = pd.DataFrame(columns = ['model','max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse'])
    pca_col_model_results =pd.DataFrame(columns = ['model','filename','iteration','column','avg_column_significance', 'column_descr'])

    print('all pca vif filtered kfold split process: ')
    for i, (train_index, test_index) in enumerate(kf10.split(train_X)):
        # print(f"Fold {i}:")
        code_names = pca_train_df.columns
        max_features = 'auto'
        max_depth = 15
        ccp_alpha = .75 #float when increasing from 0 to 1, tree is pruned more to better generalize

        percent_threshold = 0.0009

    # max_features = 'sqrt'
        max_depth = 25
        ccp_alpha = .9 #float when increasing from 0 to 1, tree is pruned more to better generalize

    # print([pca_train_df.columns.index(x) for x in vif['feature_code']])
        dt_regr = DecisionTreeRegressor(max_features= max_features, max_depth= max_depth, ccp_alpha = ccp_alpha).fit(pd.DataFrame(pca_train_df).iloc[train_index,[x for x in vif.index]], pd.DataFrame(train_y_df).iloc[train_index,:])
        dt_regr_score = dt_regr.score(pd.DataFrame(pca_train_df).iloc[test_index,[x for x in vif.index]], pd.DataFrame(train_y_df).iloc[test_index,:])
        dt_regr_predict = dt_regr.predict(pd.DataFrame(pca_test_df).iloc[:,[x for x in vif.index]])

        rmse = round(math.sqrt(mean_squared_error(train_y_df, dt_regr_predict)),3)

        pca_col_score_results = pd.DataFrame(columns = ['model','filename','iteration','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
    # print(dt_regr.feature_importances_)
        # print([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]])
        for sig_i, sig_column in enumerate([code_names[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]]):

            col_score = round([dt_regr.feature_importances_[x] for x in [list(dt_regr.feature_importances_).index(x) for x in dt_regr.feature_importances_ if x > percent_threshold]][sig_i],4)
            col_df = pd.DataFrame([[dt_regr.__class__.__name__, sig_column.split('_')[0],iter_pca
                                , dt_regr_score, rmse ,sig_column, col_score
                                ,meta_dict[sig_column.split('_')[0]]
                               ]]
                               ,columns = ['model','filename','iteration','avg_r_score','avg_rmse','column','avg_column_significance', 'column_descr'])
            # print(col_df)
            pca_col_score_results = pd.concat([pca_col_score_results, col_df], axis = 0)
        # print(pca_col_score_results)
        # model_score_results = pd.concat([model_score_results,dt_col_results[['model','max_features','max_depth','ccp_alpha','avg_r_score','avg_rmse']].drop_duplicates()],axis=0)
        pca_col_model_results = pd.concat([pca_col_model_results,pca_col_score_results[['model','filename','iteration','column','avg_column_significance', 'column_descr']]],axis=0)
        
        # print(iter_pca_col_score_results)

    print(pca_col_model_results)
    # model_score_results=model_score_results.groupby(['model','max_features','max_depth','ccp_alpha'],as_index = False).mean().reset_index()
    iter_pca_col_score_results_gp = pca_col_model_results.groupby(['model','filename','iteration','column', 'column_descr'],as_index = False)['avg_column_significance'].aggregate(['mean']).reset_index().sort_values(by=['mean'], ascending=False)
    print(iter_pca_col_score_results_gp)
    iter_pca_col_score_results = pd.concat([iter_pca_col_score_results,iter_pca_col_score_results_gp[['model','filename','iteration','column', 'column_descr','mean']]],axis=0)

print(iter_pca_col_score_results)
print(col_score_results.columns)
print(nca_pca.get_params(deep=True))

print(col_score_results.columns)
print(vif_all)
iter_pca_col_score_results['vif'] = [vif_all[vif_all['feature_code']==x]['VIF'].values[0] for x in iter_pca_col_score_results['column']]

print(iter_pca_col_score_results)
print(iter_pca_col_score_results[['iteration','column','column_descr','mean','vif']])

# iter_pca_col_score_results = iter_pca_col_score_results.rename(columns={'mean':'mean_score'})
across_pca_iter_avg = iter_pca_col_score_results.groupby(['column'],as_index = False)['mean'].aggregate(['mean']).reset_index().sort_values(by=['mean'], ascending=False)
print(across_pca_iter_avg)
iter_pca_col_score_results['overall_mean'] = [across_pca_iter_avg[across_pca_iter_avg['column']==x]['mean'].values[0] for x in iter_pca_col_score_results['column']]

column_chart_dict = {}

for iter_chart in range(1,5):
    print(iter_chart)
    iter_df = iter_pca_col_score_results[iter_pca_col_score_results['iteration'] == iter_chart].sort_values(by=['overall_mean'], ascending=False)#.iloc[:10,:]
    iter_df_more_agg = iter_df.groupby(['model','filename','iteration','column','column_descr'],as_index = False).mean().reset_index()
    print(iter_df_more_agg)
    print(iter_df)
    # iter_df['count'] = iter_df['column']
    # iter_df['count'] = [dt_col_results.groupby(['column']).size().loc[x] for x in iter_df['column']]
    print(iter_df.columns)
    iter_df = iter_df.sort_values(by=['mean'])
    column_chart_dict[iter_chart] = alt.Chart(iter_df.iloc[:5,:]).mark_bar().encode(
    x = alt.X('mean:Q'
    # ,scale = alt.Scale(domain=[iter_pca_col_score_results['mean'].min(),
    #                                                             iter_pca_col_score_results['mean'].max()])
                    , sort=alt.EncodingSortField(field="overall_mean", op='values', order='descending')
                    ),  #op="count", 
    y=alt.Y("column:O" )
    , tooltip='column_descr:O',

    color=alt.Color('vif:Q', scale= alt.Scale(range=['lightgreen','darkblue'] ))
    ).properties(height=150, width = 700)

    print(iter_df)
    print(iter_df.columns)
# Out:
# 1
# all pca vif filtered kfold split process:
#                     model filename iteration              column  \
# 0   DecisionTreeRegressor     CDIS         1    CDIS_component_2
# 0   DecisionTreeRegressor     CDIS         1    CDIS_component_3
# 0   DecisionTreeRegressor       ED         1      ED_component_0
# 0   DecisionTreeRegressor       EQ         1      EQ_component_0
# 0   DecisionTreeRegressor      FAS         1     FAS_component_0
# ..                    ...      ...       ...                 ...
# 0   DecisionTreeRegressor    FSIRE         1   FSIRE_component_0
# 0   DecisionTreeRegressor    FSIRE         1   FSIRE_component_1
# 0   DecisionTreeRegressor   GENDER         1  GENDER_component_0
# 0   DecisionTreeRegressor     HPDD         1    HPDD_component_0
# 0   DecisionTreeRegressor     CDIS         1    CDIS_component_3
#
#    avg_column_significance                                       column_descr
# 0                   0.0096        Coordinated Direct Investment Survey (CDIS)
# 0                   0.6239        Coordinated Direct Investment Survey (CDIS)
# 0                   0.0133                        Export Diversification (ED)
# 0                   0.0122                                Export Quality (EQ)
# 0                    0.002                      Financial Access Survey (FAS)
# ..                     ...                                                ...
# 0                   0.0099  Financial Soundness Indicators Reporting Entit...
# 0                   0.0062  Financial Soundness Indicators Reporting Entit...
# 0                     0.01                                             Gender
# 0                   0.0031                      Historical Public Debt (HPDD)
# 0                   0.0009        Coordinated Direct Investment Survey (CDIS)
#
# [266 rows x 6 columns]
#                     model                filename  iteration  \
# 4   DecisionTreeRegressor                    CDIS          1
# 6   DecisionTreeRegressor                      ED          1
# 5   DecisionTreeRegressor                      ED          1
# 7   DecisionTreeRegressor                      EQ          1
# 19  DecisionTreeRegressor                      FM          1
# 17  DecisionTreeRegressor                      FM          1
# 18  DecisionTreeRegressor                      FM          1
# 22  DecisionTreeRegressor                   FSIRE          1
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 23  DecisionTreeRegressor                  GENDER          1
# 21  DecisionTreeRegressor                   FSIRE          1
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 20  DecisionTreeRegressor                     FSI          1
# 24  DecisionTreeRegressor                  GENDER          1
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 2   DecisionTreeRegressor                    CDIS          1
# 0   DecisionTreeRegressor                  BOPAGG          1
# 9   DecisionTreeRegressor                     FDI          1
# 12  DecisionTreeRegressor                     FDI          1
# 3   DecisionTreeRegressor                    CDIS          1
# 8   DecisionTreeRegressor                     FAS          1
# 1   DecisionTreeRegressor                    CDIS          1
# 11  DecisionTreeRegressor                     FDI          1
# 25  DecisionTreeRegressor                    HPDD          1
# 10  DecisionTreeRegressor                     FDI          1
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
#
#                                 column  \
# 4                     CDIS_component_3
# 6                       ED_component_1
# 5                       ED_component_0
# 7                       EQ_component_0
# 19                      FM_component_2
# 17                      FM_component_0
# 18                      FM_component_1
# 22                   FSIRE_component_1
# 16  FISCALDECENTRALIZATION_component_3
# 23                  GENDER_component_0
# 21                   FSIRE_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 20                     FSI_component_0
# 24                  GENDER_component_1
# 15  FISCALDECENTRALIZATION_component_2
# 2                     CDIS_component_1
# 0                   BOPAGG_component_0
# 9                      FDI_component_0
# 12                     FDI_component_3
# 3                     CDIS_component_2
# 8                      FAS_component_0
# 1                     CDIS_component_0
# 11                     FDI_component_2
# 25                    HPDD_component_0
# 10                     FDI_component_1
# 14  FISCALDECENTRALIZATION_component_1
#
#                                          column_descr      mean
# 4         Coordinated Direct Investment Survey (CDIS)  0.221518
# 6                         Export Diversification (ED)  0.164200
# 5                         Export Diversification (ED)  0.110900
# 7                                 Export Quality (EQ)  0.094170
# 19                                Fiscal Monitor (FM)  0.040991
# 17                                Fiscal Monitor (FM)  0.034050
# 18                                Fiscal Monitor (FM)  0.031550
# 22  Financial Soundness Indicators Reporting Entit...  0.028062
# 16                            Fiscal Decentralization  0.024457
# 23                                             Gender  0.022588
# 21  Financial Soundness Indicators Reporting Entit...  0.017091
# 13                            Fiscal Decentralization  0.014075
# 20               Financial Soundness Indicators (FSI)  0.013927
# 24                                             Gender  0.011129
# 15                            Fiscal Decentralization  0.008737
# 2         Coordinated Direct Investment Survey (CDIS)  0.007700
# 0                           Balance of Payments (BOP)  0.007191
# 9                          Financial Development (FD)  0.007160
# 12                         Financial Development (FD)  0.006450
# 3         Coordinated Direct Investment Survey (CDIS)  0.005854
# 8                       Financial Access Survey (FAS)  0.005409
# 1         Coordinated Direct Investment Survey (CDIS)  0.005010
# 11                         Financial Development (FD)  0.004714
# 25                      Historical Public Debt (HPDD)  0.004464
# 10                         Financial Development (FD)  0.004336
# 14                            Fiscal Decentralization  0.003420
# 2
# all pca vif filtered kfold split process:
#                     model filename iteration              column  \
# 0   DecisionTreeRegressor     CDIS         2    CDIS_component_0
# 0   DecisionTreeRegressor     CDIS         2    CDIS_component_1
# 0   DecisionTreeRegressor     CDIS         2    CDIS_component_3
# 0   DecisionTreeRegressor       ED         2      ED_component_0
# 0   DecisionTreeRegressor       ED         2      ED_component_1
# ..                    ...      ...       ...                 ...
# 0   DecisionTreeRegressor   GENDER         2  GENDER_component_1
# 0   DecisionTreeRegressor     HPDD         2    HPDD_component_0
# 0   DecisionTreeRegressor     CDIS         2    CDIS_component_0
# 0   DecisionTreeRegressor       ED         2      ED_component_0
# 0   DecisionTreeRegressor       ED         2      ED_component_1
#
#    avg_column_significance                                 column_descr
# 0                   0.0047  Coordinated Direct Investment Survey (CDIS)
# 0                   0.0096  Coordinated Direct Investment Survey (CDIS)
# 0                   0.0433  Coordinated Direct Investment Survey (CDIS)
# 0                   0.5883                  Export Diversification (ED)
# 0                   0.0118                  Export Diversification (ED)
# ..                     ...                                          ...
# 0                     0.01                                       Gender
# 0                   0.0036                Historical Public Debt (HPDD)
# 0                   0.0029  Coordinated Direct Investment Survey (CDIS)
# 0                   0.0018                  Export Diversification (ED)
# 0                   0.0009                  Export Diversification (ED)
#
# [274 rows x 6 columns]
#                     model                filename  iteration  \
# 5   DecisionTreeRegressor                      ED          2
# 6   DecisionTreeRegressor                      ED          2
# 4   DecisionTreeRegressor                    CDIS          2
# 7   DecisionTreeRegressor                      EQ          2
# 17  DecisionTreeRegressor                      FM          2
# 19  DecisionTreeRegressor                      FM          2
# 21  DecisionTreeRegressor                   FSIRE          2
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION          2
# 18  DecisionTreeRegressor                      FM          2
# 22  DecisionTreeRegressor                   FSIRE          2
# 20  DecisionTreeRegressor                     FSI          2
# 23  DecisionTreeRegressor                  GENDER          2
# 12  DecisionTreeRegressor                     FDI          2
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION          2
# 24  DecisionTreeRegressor                  GENDER          2
# 25  DecisionTreeRegressor                    HPDD          2
# 9   DecisionTreeRegressor                     FDI          2
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION          2
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION          2
# 1   DecisionTreeRegressor                    CDIS          2
# 8   DecisionTreeRegressor                     FAS          2
# 3   DecisionTreeRegressor                    CDIS          2
# 0   DecisionTreeRegressor                  BOPAGG          2
# 2   DecisionTreeRegressor                    CDIS          2
# 10  DecisionTreeRegressor                     FDI          2
# 11  DecisionTreeRegressor                     FDI          2
#
#                                 column  \
# 5                       ED_component_0
# 6                       ED_component_1
# 4                     CDIS_component_3
# 7                       EQ_component_0
# 17                      FM_component_0
# 19                      FM_component_2
# 21                   FSIRE_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 18                      FM_component_1
# 22                   FSIRE_component_1
# 20                     FSI_component_0
# 23                  GENDER_component_0
# 12                     FDI_component_3
# 15  FISCALDECENTRALIZATION_component_2
# 24                  GENDER_component_1
# 25                    HPDD_component_0
# 9                      FDI_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 13  FISCALDECENTRALIZATION_component_0
# 1                     CDIS_component_0
# 8                      FAS_component_0
# 3                     CDIS_component_2
# 0                   BOPAGG_component_0
# 2                     CDIS_component_1
# 10                     FDI_component_1
# 11                     FDI_component_2
#
#                                          column_descr      mean
# 5                         Export Diversification (ED)  0.172587
# 6                         Export Diversification (ED)  0.132620
# 4         Coordinated Direct Investment Survey (CDIS)  0.108377
# 7                                 Export Quality (EQ)  0.054057
# 17                                Fiscal Monitor (FM)  0.045967
# 19                                Fiscal Monitor (FM)  0.037490
# 21  Financial Soundness Indicators Reporting Entit...  0.036859
# 16                            Fiscal Decentralization  0.022629
# 18                                Fiscal Monitor (FM)  0.020920
# 22  Financial Soundness Indicators Reporting Entit...  0.019790
# 20               Financial Soundness Indicators (FSI)  0.013940
# 23                                             Gender  0.011330
# 12                         Financial Development (FD)  0.010975
# 15                            Fiscal Decentralization  0.010756
# 24                                             Gender  0.009629
# 25                      Historical Public Debt (HPDD)  0.008822
# 9                          Financial Development (FD)  0.008044
# 14                            Fiscal Decentralization  0.007900
# 13                            Fiscal Decentralization  0.007680
# 1         Coordinated Direct Investment Survey (CDIS)  0.006643
# 8                       Financial Access Survey (FAS)  0.006008
# 3         Coordinated Direct Investment Survey (CDIS)  0.005014
# 0                           Balance of Payments (BOP)  0.004600
# 2         Coordinated Direct Investment Survey (CDIS)  0.004364
# 10                         Financial Development (FD)  0.004243
# 11                         Financial Development (FD)  0.003575
# 3
# all pca vif filtered kfold split process:
#                     model filename iteration              column  \
# 0   DecisionTreeRegressor     CDIS         3    CDIS_component_0
# 0   DecisionTreeRegressor     CDIS         3    CDIS_component_3
# 0   DecisionTreeRegressor       ED         3      ED_component_0
# 0   DecisionTreeRegressor       ED         3      ED_component_1
# 0   DecisionTreeRegressor       EQ         3      EQ_component_0
# ..                    ...      ...       ...                 ...
# 0   DecisionTreeRegressor    FSIRE         3   FSIRE_component_1
# 0   DecisionTreeRegressor   GENDER         3  GENDER_component_0
# 0   DecisionTreeRegressor   GENDER         3  GENDER_component_1
# 0   DecisionTreeRegressor     CDIS         3    CDIS_component_0
# 0   DecisionTreeRegressor       ED         3      ED_component_1
#
#    avg_column_significance                                       column_descr
# 0                   0.0096        Coordinated Direct Investment Survey (CDIS)
# 0                   0.0428        Coordinated Direct Investment Survey (CDIS)
# 0                   0.5767                        Export Diversification (ED)
# 0                   0.0501                        Export Diversification (ED)
# 0                   0.0011                                Export Quality (EQ)
# ..                     ...                                                ...
# 0                   0.0019  Financial Soundness Indicators Reporting Entit...
# 0                   0.0135                                             Gender
# 0                     0.01                                             Gender
# 0                   0.0047        Coordinated Direct Investment Survey (CDIS)
# 0                   0.0018                        Export Diversification (ED)
#
# [288 rows x 6 columns]
#                     model                filename  iteration  \
# 5   DecisionTreeRegressor                      ED          3
# 7   DecisionTreeRegressor                      EQ          3
# 6   DecisionTreeRegressor                      ED          3
# 4   DecisionTreeRegressor                    CDIS          3
# 18  DecisionTreeRegressor                      FM          3
# 17  DecisionTreeRegressor                      FM          3
# 19  DecisionTreeRegressor                      FM          3
# 24  DecisionTreeRegressor                  GENDER          3
# 21  DecisionTreeRegressor                   FSIRE          3
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION          3
# 20  DecisionTreeRegressor                     FSI          3
# 23  DecisionTreeRegressor                  GENDER          3
# 22  DecisionTreeRegressor                   FSIRE          3
# 25  DecisionTreeRegressor                    HPDD          3
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION          3
# 10  DecisionTreeRegressor                     FDI          3
# 12  DecisionTreeRegressor                     FDI          3
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION          3
# 1   DecisionTreeRegressor                    CDIS          3
# 8   DecisionTreeRegressor                     FAS          3
# 2   DecisionTreeRegressor                    CDIS          3
# 9   DecisionTreeRegressor                     FDI          3
# 3   DecisionTreeRegressor                    CDIS          3
# 0   DecisionTreeRegressor                  BOPAGG          3
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION          3
# 11  DecisionTreeRegressor                     FDI          3
#
#                                 column  \
# 5                       ED_component_0
# 7                       EQ_component_0
# 6                       ED_component_1
# 4                     CDIS_component_3
# 18                      FM_component_1
# 17                      FM_component_0
# 19                      FM_component_2
# 24                  GENDER_component_1
# 21                   FSIRE_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 20                     FSI_component_0
# 23                  GENDER_component_0
# 22                   FSIRE_component_1
# 25                    HPDD_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 10                     FDI_component_1
# 12                     FDI_component_3
# 14  FISCALDECENTRALIZATION_component_1
# 1                     CDIS_component_0
# 8                      FAS_component_0
# 2                     CDIS_component_1
# 9                      FDI_component_0
# 3                     CDIS_component_2
# 0                   BOPAGG_component_0
# 15  FISCALDECENTRALIZATION_component_2
# 11                     FDI_component_2
#
#                                          column_descr      mean
# 5                         Export Diversification (ED)  0.180418
# 7                                 Export Quality (EQ)  0.133945
# 6                         Export Diversification (ED)  0.090247
# 4         Coordinated Direct Investment Survey (CDIS)  0.062977
# 18                                Fiscal Monitor (FM)  0.032767
# 17                                Fiscal Monitor (FM)  0.031753
# 19                                Fiscal Monitor (FM)  0.022733
# 24                                             Gender  0.022150
# 21  Financial Soundness Indicators Reporting Entit...  0.022110
# 16                            Fiscal Decentralization  0.019550
# 20               Financial Soundness Indicators (FSI)  0.018223
# 23                                             Gender  0.017983
# 22  Financial Soundness Indicators Reporting Entit...  0.017717
# 25                      Historical Public Debt (HPDD)  0.010318
# 13                            Fiscal Decentralization  0.010038
# 10                         Financial Development (FD)  0.009800
# 12                         Financial Development (FD)  0.009050
# 14                            Fiscal Decentralization  0.008283
# 1         Coordinated Direct Investment Survey (CDIS)  0.007546
# 8                       Financial Access Survey (FAS)  0.006075
# 2         Coordinated Direct Investment Survey (CDIS)  0.005875
# 9                          Financial Development (FD)  0.005593
# 3         Coordinated Direct Investment Survey (CDIS)  0.004754
# 0                           Balance of Payments (BOP)  0.004638
# 15                            Fiscal Decentralization  0.004633
# 11                         Financial Development (FD)  0.004060
# 4
# all pca vif filtered kfold split process:
#                     model filename iteration              column  \
# 0   DecisionTreeRegressor     CDIS         4    CDIS_component_0
# 0   DecisionTreeRegressor     CDIS         4    CDIS_component_2
# 0   DecisionTreeRegressor     CDIS         4    CDIS_component_3
# 0   DecisionTreeRegressor       ED         4      ED_component_0
# 0   DecisionTreeRegressor       EQ         4      EQ_component_0
# ..                    ...      ...       ...                 ...
# 0   DecisionTreeRegressor   GENDER         4  GENDER_component_1
# 0   DecisionTreeRegressor     HPDD         4    HPDD_component_0
# 0   DecisionTreeRegressor   BOPAGG         4  BOPAGG_component_0
# 0   DecisionTreeRegressor       ED         4      ED_component_1
# 0   DecisionTreeRegressor       EQ         4      EQ_component_0
#
#    avg_column_significance                                 column_descr
# 0                   0.0096  Coordinated Direct Investment Survey (CDIS)
# 0                   0.0047  Coordinated Direct Investment Survey (CDIS)
# 0                    0.005  Coordinated Direct Investment Survey (CDIS)
# 0                   0.5768                  Export Diversification (ED)
# 0                    0.065                          Export Quality (EQ)
# ..                     ...                                          ...
# 0                   0.0064                                       Gender
# 0                   0.0063                Historical Public Debt (HPDD)
# 0                   0.0012                    Balance of Payments (BOP)
# 0                   0.0018                  Export Diversification (ED)
# 0                    0.034                          Export Quality (EQ)
#
# [270 rows x 6 columns]
#                     model                filename  iteration  \
# 4   DecisionTreeRegressor                    CDIS          4
# 7   DecisionTreeRegressor                      EQ          4
# 5   DecisionTreeRegressor                      ED          4
# 6   DecisionTreeRegressor                      ED          4
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION          4
# 21  DecisionTreeRegressor                   FSIRE          4
# 18  DecisionTreeRegressor                      FM          4
# 17  DecisionTreeRegressor                      FM          4
# 20  DecisionTreeRegressor                     FSI          4
# 23  DecisionTreeRegressor                  GENDER          4
# 22  DecisionTreeRegressor                   FSIRE          4
# 24  DecisionTreeRegressor                  GENDER          4
# 12  DecisionTreeRegressor                     FDI          4
# 19  DecisionTreeRegressor                      FM          4
# 11  DecisionTreeRegressor                     FDI          4
# 3   DecisionTreeRegressor                    CDIS          4
# 2   DecisionTreeRegressor                    CDIS          4
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION          4
# 9   DecisionTreeRegressor                     FDI          4
# 1   DecisionTreeRegressor                    CDIS          4
# 8   DecisionTreeRegressor                     FAS          4
# 25  DecisionTreeRegressor                    HPDD          4
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION          4
# 0   DecisionTreeRegressor                  BOPAGG          4
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION          4
# 10  DecisionTreeRegressor                     FDI          4
#
#                                 column  \
# 4                     CDIS_component_3
# 7                       EQ_component_0
# 5                       ED_component_0
# 6                       ED_component_1
# 16  FISCALDECENTRALIZATION_component_3
# 21                   FSIRE_component_0
# 18                      FM_component_1
# 17                      FM_component_0
# 20                     FSI_component_0
# 23                  GENDER_component_0
# 22                   FSIRE_component_1
# 24                  GENDER_component_1
# 12                     FDI_component_3
# 19                      FM_component_2
# 11                     FDI_component_2
# 3                     CDIS_component_2
# 2                     CDIS_component_1
# 14  FISCALDECENTRALIZATION_component_1
# 9                      FDI_component_0
# 1                     CDIS_component_0
# 8                      FAS_component_0
# 25                    HPDD_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 0                   BOPAGG_component_0
# 15  FISCALDECENTRALIZATION_component_2
# 10                     FDI_component_1
#
#                                          column_descr      mean
# 4         Coordinated Direct Investment Survey (CDIS)  0.221600
# 7                                 Export Quality (EQ)  0.137633
# 5                         Export Diversification (ED)  0.104669
# 6                         Export Diversification (ED)  0.080969
# 16                            Fiscal Decentralization  0.058614
# 21  Financial Soundness Indicators Reporting Entit...  0.039217
# 18                                Fiscal Monitor (FM)  0.036360
# 17                                Fiscal Monitor (FM)  0.035136
# 20               Financial Soundness Indicators (FSI)  0.024862
# 23                                             Gender  0.022409
# 22  Financial Soundness Indicators Reporting Entit...  0.017480
# 24                                             Gender  0.017185
# 12                         Financial Development (FD)  0.016086
# 19                                Fiscal Monitor (FM)  0.015309
# 11                         Financial Development (FD)  0.011960
# 3         Coordinated Direct Investment Survey (CDIS)  0.006122
# 2         Coordinated Direct Investment Survey (CDIS)  0.006025
# 14                            Fiscal Decentralization  0.005962
# 9                          Financial Development (FD)  0.005455
# 1         Coordinated Direct Investment Survey (CDIS)  0.005050
# 8                       Financial Access Survey (FAS)  0.004800
# 25                      Historical Public Debt (HPDD)  0.004513
# 13                            Fiscal Decentralization  0.004433
# 0                           Balance of Payments (BOP)  0.004160
# 15                            Fiscal Decentralization  0.003110
# 10                         Financial Development (FD)  0.001800
#                     model                filename iteration  \
# 4   DecisionTreeRegressor                    CDIS         1
# 6   DecisionTreeRegressor                      ED         1
# 5   DecisionTreeRegressor                      ED         1
# 7   DecisionTreeRegressor                      EQ         1
# 19  DecisionTreeRegressor                      FM         1
# ..                    ...                     ...       ...
# 25  DecisionTreeRegressor                    HPDD         4
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 0   DecisionTreeRegressor                  BOPAGG         4
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 10  DecisionTreeRegressor                     FDI         4
#
#                                 column  \
# 4                     CDIS_component_3
# 6                       ED_component_1
# 5                       ED_component_0
# 7                       EQ_component_0
# 19                      FM_component_2
# ..                                 ...
# 25                    HPDD_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 0                   BOPAGG_component_0
# 15  FISCALDECENTRALIZATION_component_2
# 10                     FDI_component_1
#
#                                    column_descr avg_column_significance  \
# 4   Coordinated Direct Investment Survey (CDIS)                     NaN
# 6                   Export Diversification (ED)                     NaN
# 5                   Export Diversification (ED)                     NaN
# 7                           Export Quality (EQ)                     NaN
# 19                          Fiscal Monitor (FM)                     NaN
# ..                                          ...                     ...
# 25                Historical Public Debt (HPDD)                     NaN
# 13                      Fiscal Decentralization                     NaN
# 0                     Balance of Payments (BOP)                     NaN
# 15                      Fiscal Decentralization                     NaN
# 10                   Financial Development (FD)                     NaN
#
#         mean
# 4   0.221518
# 6   0.164200
# 5   0.110900
# 7   0.094170
# 19  0.040991
# ..       ...
# 25  0.004513
# 13  0.004433
# 0   0.004160
# 15  0.003110
# 10  0.001800
#
# [104 rows x 7 columns]
# Index(['model', 'filename', 'column', 'column_descr', 'mean', 'vif'], dtype='object')
# {'copy': True, 'iterated_power': 'auto', 'n_components': 0.95, 'random_state': None, 'svd_solver': 'auto', 'tol': 0.0, 'whiten': False}
# Index(['model', 'filename', 'column', 'column_descr', 'mean', 'vif'], dtype='object')
#                           feature_code           VIF  \
# 92  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 66  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 40  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 14  FISCALDECENTRALIZATION_component_1  1.008100e+00
# 91  FISCALDECENTRALIZATION_component_0  1.010600e+00
# ..                                 ...           ...
# 47                   FSIRE_component_0  1.112123e+11
# 54                    CDIS_component_1  4.012294e+11
# 46                     FSI_component_0  1.251000e+12
# 20                     FSI_component_0  1.954687e+12
# 98                     FSI_component_0           inf
#
#                                          feature_name
# 92                            Fiscal Decentralization
# 66                            Fiscal Decentralization
# 40                            Fiscal Decentralization
# 14                            Fiscal Decentralization
# 91                            Fiscal Decentralization
# ..                                                ...
# 47  Financial Soundness Indicators Reporting Entit...
# 54        Coordinated Direct Investment Survey (CDIS)
# 46               Financial Soundness Indicators (FSI)
# 20               Financial Soundness Indicators (FSI)
# 98               Financial Soundness Indicators (FSI)
#
# [104 rows x 3 columns]
#                     model                filename iteration  \
# 4   DecisionTreeRegressor                    CDIS         1
# 6   DecisionTreeRegressor                      ED         1
# 5   DecisionTreeRegressor                      ED         1
# 7   DecisionTreeRegressor                      EQ         1
# 19  DecisionTreeRegressor                      FM         1
# ..                    ...                     ...       ...
# 25  DecisionTreeRegressor                    HPDD         4
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 0   DecisionTreeRegressor                  BOPAGG         4
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 10  DecisionTreeRegressor                     FDI         4
#
#                                 column  \
# 4                     CDIS_component_3
# 6                       ED_component_1
# 5                       ED_component_0
# 7                       EQ_component_0
# 19                      FM_component_2
# ..                                 ...
# 25                    HPDD_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 0                   BOPAGG_component_0
# 15  FISCALDECENTRALIZATION_component_2
# 10                     FDI_component_1
#
#                                    column_descr avg_column_significance  \
# 4   Coordinated Direct Investment Survey (CDIS)                     NaN
# 6                   Export Diversification (ED)                     NaN
# 5                   Export Diversification (ED)                     NaN
# 7                           Export Quality (EQ)                     NaN
# 19                          Fiscal Monitor (FM)                     NaN
# ..                                          ...                     ...
# 25                Historical Public Debt (HPDD)                     NaN
# 13                      Fiscal Decentralization                     NaN
# 0                     Balance of Payments (BOP)                     NaN
# 15                      Fiscal Decentralization                     NaN
# 10                   Financial Development (FD)                     NaN
#
#         mean           vif
# 4   0.221518  4.745166e+06
# 6   0.164200  1.044900e+00
# 5   0.110900  1.159800e+00
# 7   0.094170  2.047621e+03
# 19  0.040991  1.075500e+00
# ..       ...           ...
# 25  0.004513  1.045100e+00
# 13  0.004433  1.010600e+00
# 0   0.004160  5.128073e+07
# 15  0.003110  2.750100e+00
# 10  0.001800  1.192900e+00
#
# [104 rows x 8 columns]
#    iteration                              column  \
# 4          1                    CDIS_component_3
# 6          1                      ED_component_1
# 5          1                      ED_component_0
# 7          1                      EQ_component_0
# 19         1                      FM_component_2
# ..       ...                                 ...
# 25         4                    HPDD_component_0
# 13         4  FISCALDECENTRALIZATION_component_0
# 0          4                  BOPAGG_component_0
# 15         4  FISCALDECENTRALIZATION_component_2
# 10         4                     FDI_component_1
#
#                                    column_descr      mean           vif
# 4   Coordinated Direct Investment Survey (CDIS)  0.221518  4.745166e+06
# 6                   Export Diversification (ED)  0.164200  1.044900e+00
# 5                   Export Diversification (ED)  0.110900  1.159800e+00
# 7                           Export Quality (EQ)  0.094170  2.047621e+03
# 19                          Fiscal Monitor (FM)  0.040991  1.075500e+00
# ..                                          ...       ...           ...
# 25                Historical Public Debt (HPDD)  0.004513  1.045100e+00
# 13                      Fiscal Decentralization  0.004433  1.010600e+00
# 0                     Balance of Payments (BOP)  0.004160  5.128073e+07
# 15                      Fiscal Decentralization  0.003110  2.750100e+00
# 10                   Financial Development (FD)  0.001800  1.192900e+00
#
# [104 rows x 5 columns]
#                                 column      mean
# 4                     CDIS_component_3  0.153618
# 5                       ED_component_0  0.142143
# 6                       ED_component_1  0.117009
# 7                       EQ_component_0  0.104951
# 17                      FM_component_0  0.036727
# 16  FISCALDECENTRALIZATION_component_3  0.031313
# 18                      FM_component_1  0.030399
# 19                      FM_component_2  0.029131
# 20                   FSIRE_component_0  0.028819
# 21                   FSIRE_component_1  0.020762
# 23                  GENDER_component_0  0.018577
# 22                     FSI_component_0  0.017738
# 24                  GENDER_component_1  0.015023
# 12                     FDI_component_3  0.010640
# 13  FISCALDECENTRALIZATION_component_0  0.009056
# 25                    HPDD_component_0  0.007029
# 15  FISCALDECENTRALIZATION_component_2  0.006809
# 9                      FDI_component_0  0.006563
# 14  FISCALDECENTRALIZATION_component_1  0.006391
# 11                     FDI_component_2  0.006077
# 1                     CDIS_component_0  0.006062
# 2                     CDIS_component_1  0.005991
# 8                      FAS_component_0  0.005573
# 3                     CDIS_component_2  0.005436
# 0                   BOPAGG_component_0  0.005147
# 10                     FDI_component_1  0.005045
# 1
#     index                  model                filename  iteration  \
# 0       0  DecisionTreeRegressor                  BOPAGG          1
# 1       1  DecisionTreeRegressor                    CDIS          1
# 2       2  DecisionTreeRegressor                    CDIS          1
# 3       3  DecisionTreeRegressor                    CDIS          1
# 4       4  DecisionTreeRegressor                    CDIS          1
# 5       5  DecisionTreeRegressor                      ED          1
# 6       6  DecisionTreeRegressor                      ED          1
# 7       7  DecisionTreeRegressor                      EQ          1
# 8       8  DecisionTreeRegressor                     FAS          1
# 9       9  DecisionTreeRegressor                     FDI          1
# 10     10  DecisionTreeRegressor                     FDI          1
# 11     11  DecisionTreeRegressor                     FDI          1
# 12     12  DecisionTreeRegressor                     FDI          1
# 13     13  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 14     14  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 15     15  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 16     16  DecisionTreeRegressor  FISCALDECENTRALIZATION          1
# 17     17  DecisionTreeRegressor                      FM          1
# 18     18  DecisionTreeRegressor                      FM          1
# 19     19  DecisionTreeRegressor                      FM          1
# 20     20  DecisionTreeRegressor                     FSI          1
# 21     21  DecisionTreeRegressor                   FSIRE          1
# 22     22  DecisionTreeRegressor                   FSIRE          1
# 23     23  DecisionTreeRegressor                  GENDER          1
# 24     24  DecisionTreeRegressor                  GENDER          1
# 25     25  DecisionTreeRegressor                    HPDD          1
#
#                                 column  \
# 0                   BOPAGG_component_0
# 1                     CDIS_component_0
# 2                     CDIS_component_1
# 3                     CDIS_component_2
# 4                     CDIS_component_3
# 5                       ED_component_0
# 6                       ED_component_1
# 7                       EQ_component_0
# 8                      FAS_component_0
# 9                      FDI_component_0
# 10                     FDI_component_1
# 11                     FDI_component_2
# 12                     FDI_component_3
# 13  FISCALDECENTRALIZATION_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 15  FISCALDECENTRALIZATION_component_2
# 16  FISCALDECENTRALIZATION_component_3
# 17                      FM_component_0
# 18                      FM_component_1
# 19                      FM_component_2
# 20                     FSI_component_0
# 21                   FSIRE_component_0
# 22                   FSIRE_component_1
# 23                  GENDER_component_0
# 24                  GENDER_component_1
# 25                    HPDD_component_0
#
#                                          column_descr      mean           vif  \
# 0                           Balance of Payments (BOP)  0.007191  5.128073e+07
# 1         Coordinated Direct Investment Survey (CDIS)  0.005010  6.978410e+07
# 2         Coordinated Direct Investment Survey (CDIS)  0.007700  7.733078e+07
# 3         Coordinated Direct Investment Survey (CDIS)  0.005854  2.224804e+06
# 4         Coordinated Direct Investment Survey (CDIS)  0.221518  4.745166e+06
# 5                         Export Diversification (ED)  0.110900  1.159800e+00
# 6                         Export Diversification (ED)  0.164200  1.044900e+00
# 7                                 Export Quality (EQ)  0.094170  2.047621e+03
# 8                       Financial Access Survey (FAS)  0.005409  1.026327e+09
# 9                          Financial Development (FD)  0.007160  2.286400e+00
# 10                         Financial Development (FD)  0.004336  1.192900e+00
# 11                         Financial Development (FD)  0.004714  1.167800e+00
# 12                         Financial Development (FD)  0.006450  1.046600e+00
# 13                            Fiscal Decentralization  0.014075  1.010600e+00
# 14                            Fiscal Decentralization  0.003420  1.008100e+00
# 15                            Fiscal Decentralization  0.008737  2.750100e+00
# 16                            Fiscal Decentralization  0.024457  1.560500e+00
# 17                                Fiscal Monitor (FM)  0.034050  1.075500e+00
# 18                                Fiscal Monitor (FM)  0.031550  1.062100e+00
# 19                                Fiscal Monitor (FM)  0.040991  1.075500e+00
# 20               Financial Soundness Indicators (FSI)  0.013927  6.763741e+09
# 21  Financial Soundness Indicators Reporting Entit...  0.017091  3.669233e+09
# 22  Financial Soundness Indicators Reporting Entit...  0.028062  1.237752e+09
# 23                                             Gender  0.022588  1.163700e+00
# 24                                             Gender  0.011129  1.019600e+00
# 25                      Historical Public Debt (HPDD)  0.004464  1.045100e+00
#
#     overall_mean
# 0       0.005147
# 1       0.006062
# 2       0.005991
# 3       0.005436
# 4       0.153618
# 5       0.142143
# 6       0.117009
# 7       0.104951
# 8       0.005573
# 9       0.006563
# 10      0.005045
# 11      0.006077
# 12      0.010640
# 13      0.009056
# 14      0.006391
# 15      0.006809
# 16      0.031313
# 17      0.036727
# 18      0.030399
# 19      0.029131
# 20      0.017738
# 21      0.028819
# 22      0.020762
# 23      0.018577
# 24      0.015023
# 25      0.007029
#                     model                filename iteration  \
# 4   DecisionTreeRegressor                    CDIS         1
# 5   DecisionTreeRegressor                      ED         1
# 6   DecisionTreeRegressor                      ED         1
# 7   DecisionTreeRegressor                      EQ         1
# 17  DecisionTreeRegressor                      FM         1
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION         1
# 18  DecisionTreeRegressor                      FM         1
# 19  DecisionTreeRegressor                      FM         1
# 21  DecisionTreeRegressor                   FSIRE         1
# 22  DecisionTreeRegressor                   FSIRE         1
# 23  DecisionTreeRegressor                  GENDER         1
# 20  DecisionTreeRegressor                     FSI         1
# 24  DecisionTreeRegressor                  GENDER         1
# 12  DecisionTreeRegressor                     FDI         1
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION         1
# 25  DecisionTreeRegressor                    HPDD         1
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION         1
# 9   DecisionTreeRegressor                     FDI         1
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION         1
# 11  DecisionTreeRegressor                     FDI         1
# 1   DecisionTreeRegressor                    CDIS         1
# 2   DecisionTreeRegressor                    CDIS         1
# 8   DecisionTreeRegressor                     FAS         1
# 3   DecisionTreeRegressor                    CDIS         1
# 0   DecisionTreeRegressor                  BOPAGG         1
# 10  DecisionTreeRegressor                     FDI         1
#
#                                 column  \
# 4                     CDIS_component_3
# 5                       ED_component_0
# 6                       ED_component_1
# 7                       EQ_component_0
# 17                      FM_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 18                      FM_component_1
# 19                      FM_component_2
# 21                   FSIRE_component_0
# 22                   FSIRE_component_1
# 23                  GENDER_component_0
# 20                     FSI_component_0
# 24                  GENDER_component_1
# 12                     FDI_component_3
# 13  FISCALDECENTRALIZATION_component_0
# 25                    HPDD_component_0
# 15  FISCALDECENTRALIZATION_component_2
# 9                      FDI_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 11                     FDI_component_2
# 1                     CDIS_component_0
# 2                     CDIS_component_1
# 8                      FAS_component_0
# 3                     CDIS_component_2
# 0                   BOPAGG_component_0
# 10                     FDI_component_1
#
#                                          column_descr avg_column_significance  \
# 4         Coordinated Direct Investment Survey (CDIS)                     NaN
# 5                         Export Diversification (ED)                     NaN
# 6                         Export Diversification (ED)                     NaN
# 7                                 Export Quality (EQ)                     NaN
# 17                                Fiscal Monitor (FM)                     NaN
# 16                            Fiscal Decentralization                     NaN
# 18                                Fiscal Monitor (FM)                     NaN
# 19                                Fiscal Monitor (FM)                     NaN
# 21  Financial Soundness Indicators Reporting Entit...                     NaN
# 22  Financial Soundness Indicators Reporting Entit...                     NaN
# 23                                             Gender                     NaN
# 20               Financial Soundness Indicators (FSI)                     NaN
# 24                                             Gender                     NaN
# 12                         Financial Development (FD)                     NaN
# 13                            Fiscal Decentralization                     NaN
# 25                      Historical Public Debt (HPDD)                     NaN
# 15                            Fiscal Decentralization                     NaN
# 9                          Financial Development (FD)                     NaN
# 14                            Fiscal Decentralization                     NaN
# 11                         Financial Development (FD)                     NaN
# 1         Coordinated Direct Investment Survey (CDIS)                     NaN
# 2         Coordinated Direct Investment Survey (CDIS)                     NaN
# 8                       Financial Access Survey (FAS)                     NaN
# 3         Coordinated Direct Investment Survey (CDIS)                     NaN
# 0                           Balance of Payments (BOP)                     NaN
# 10                         Financial Development (FD)                     NaN
#
#         mean           vif  overall_mean
# 4   0.221518  4.745166e+06      0.153618
# 5   0.110900  1.159800e+00      0.142143
# 6   0.164200  1.044900e+00      0.117009
# 7   0.094170  2.047621e+03      0.104951
# 17  0.034050  1.075500e+00      0.036727
# 16  0.024457  1.560500e+00      0.031313
# 18  0.031550  1.062100e+00      0.030399
# 19  0.040991  1.075500e+00      0.029131
# 21  0.017091  3.669233e+09      0.028819
# 22  0.028062  1.237752e+09      0.020762
# 23  0.022588  1.163700e+00      0.018577
# 20  0.013927  6.763741e+09      0.017738
# 24  0.011129  1.019600e+00      0.015023
# 12  0.006450  1.046600e+00      0.010640
# 13  0.014075  1.010600e+00      0.009056
# 25  0.004464  1.045100e+00      0.007029
# 15  0.008737  2.750100e+00      0.006809
# 9   0.007160  2.286400e+00      0.006563
# 14  0.003420  1.008100e+00      0.006391
# 11  0.004714  1.167800e+00      0.006077
# 1   0.005010  6.978410e+07      0.006062
# 2   0.007700  7.733078e+07      0.005991
# 8   0.005409  1.026327e+09      0.005573
# 3   0.005854  2.224804e+06      0.005436
# 0   0.007191  5.128073e+07      0.005147
# 10  0.004336  1.192900e+00      0.005045
# Index(['model', 'filename', 'iteration', 'column', 'column_descr',
#        'avg_column_significance', 'mean', 'vif', 'overall_mean'],
#       dtype='object')
#                     model                filename iteration  \
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION         1
# 10  DecisionTreeRegressor                     FDI         1
# 25  DecisionTreeRegressor                    HPDD         1
# 11  DecisionTreeRegressor                     FDI         1
# 1   DecisionTreeRegressor                    CDIS         1
# 8   DecisionTreeRegressor                     FAS         1
# 3   DecisionTreeRegressor                    CDIS         1
# 12  DecisionTreeRegressor                     FDI         1
# 9   DecisionTreeRegressor                     FDI         1
# ...
# 12                     FDI_component_3
# 13  FISCALDECENTRALIZATION_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 15  FISCALDECENTRALIZATION_component_2
# 16  FISCALDECENTRALIZATION_component_3
# 17                      FM_component_0
# 18                      FM_component_1
# 19                      FM_component_2
# 20                     FSI_component_0
# 21                   FSIRE_component_0
# 22                   FSIRE_component_1
# 23                  GENDER_component_0
# 24                  GENDER_component_1
# 25                    HPDD_component_0
#
#                                          column_descr      mean           vif  \
# 0                           Balance of Payments (BOP)  0.004160  5.128073e+07
# 1         Coordinated Direct Investment Survey (CDIS)  0.005050  6.978410e+07
# 2         Coordinated Direct Investment Survey (CDIS)  0.006025  7.733078e+07
# 3         Coordinated Direct Investment Survey (CDIS)  0.006122  2.224804e+06
# 4         Coordinated Direct Investment Survey (CDIS)  0.221600  4.745166e+06
# 5                         Export Diversification (ED)  0.104669  1.159800e+00
# 6                         Export Diversification (ED)  0.080969  1.044900e+00
# 7                                 Export Quality (EQ)  0.137633  2.047621e+03
# 8                       Financial Access Survey (FAS)  0.004800  1.026327e+09
# 9                          Financial Development (FD)  0.005455  2.286400e+00
# 10                         Financial Development (FD)  0.001800  1.192900e+00
# 11                         Financial Development (FD)  0.011960  1.167800e+00
# 12                         Financial Development (FD)  0.016086  1.046600e+00
# 13                            Fiscal Decentralization  0.004433  1.010600e+00
# 14                            Fiscal Decentralization  0.005962  1.008100e+00
# 15                            Fiscal Decentralization  0.003110  2.750100e+00
# 16                            Fiscal Decentralization  0.058614  1.560500e+00
# 17                                Fiscal Monitor (FM)  0.035136  1.075500e+00
# 18                                Fiscal Monitor (FM)  0.036360  1.062100e+00
# 19                                Fiscal Monitor (FM)  0.015309  1.075500e+00
# 20               Financial Soundness Indicators (FSI)  0.024862  6.763741e+09
# 21  Financial Soundness Indicators Reporting Entit...  0.039217  3.669233e+09
# 22  Financial Soundness Indicators Reporting Entit...  0.017480  1.237752e+09
# 23                                             Gender  0.022409  1.163700e+00
# 24                                             Gender  0.017185  1.019600e+00
# 25                      Historical Public Debt (HPDD)  0.004513  1.045100e+00
#
#     overall_mean
# 0       0.005147
# 1       0.006062
# 2       0.005991
# 3       0.005436
# 4       0.153618
# 5       0.142143
# 6       0.117009
# 7       0.104951
# 8       0.005573
# 9       0.006563
# 10      0.005045
# 11      0.006077
# 12      0.010640
# 13      0.009056
# 14      0.006391
# 15      0.006809
# 16      0.031313
# 17      0.036727
# 18      0.030399
# 19      0.029131
# 20      0.017738
# 21      0.028819
# 22      0.020762
# 23      0.018577
# 24      0.015023
# 25      0.007029
#                     model                filename iteration  \
# 4   DecisionTreeRegressor                    CDIS         4
# 5   DecisionTreeRegressor                      ED         4
# 6   DecisionTreeRegressor                      ED         4
# 7   DecisionTreeRegressor                      EQ         4
# 17  DecisionTreeRegressor                      FM         4
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 18  DecisionTreeRegressor                      FM         4
# 19  DecisionTreeRegressor                      FM         4
# 21  DecisionTreeRegressor                   FSIRE         4
# 22  DecisionTreeRegressor                   FSIRE         4
# 23  DecisionTreeRegressor                  GENDER         4
# 20  DecisionTreeRegressor                     FSI         4
# 24  DecisionTreeRegressor                  GENDER         4
# 12  DecisionTreeRegressor                     FDI         4
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 25  DecisionTreeRegressor                    HPDD         4
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 9   DecisionTreeRegressor                     FDI         4
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 11  DecisionTreeRegressor                     FDI         4
# 1   DecisionTreeRegressor                    CDIS         4
# 2   DecisionTreeRegressor                    CDIS         4
# 8   DecisionTreeRegressor                     FAS         4
# 3   DecisionTreeRegressor                    CDIS         4
# 0   DecisionTreeRegressor                  BOPAGG         4
# 10  DecisionTreeRegressor                     FDI         4
#
#                                 column  \
# 4                     CDIS_component_3
# 5                       ED_component_0
# 6                       ED_component_1
# 7                       EQ_component_0
# 17                      FM_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 18                      FM_component_1
# 19                      FM_component_2
# 21                   FSIRE_component_0
# 22                   FSIRE_component_1
# 23                  GENDER_component_0
# 20                     FSI_component_0
# 24                  GENDER_component_1
# 12                     FDI_component_3
# 13  FISCALDECENTRALIZATION_component_0
# 25                    HPDD_component_0
# 15  FISCALDECENTRALIZATION_component_2
# 9                      FDI_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 11                     FDI_component_2
# 1                     CDIS_component_0
# 2                     CDIS_component_1
# 8                      FAS_component_0
# 3                     CDIS_component_2
# 0                   BOPAGG_component_0
# 10                     FDI_component_1
#
#                                          column_descr avg_column_significance  \
# 4         Coordinated Direct Investment Survey (CDIS)                     NaN
# 5                         Export Diversification (ED)                     NaN
# 6                         Export Diversification (ED)                     NaN
# 7                                 Export Quality (EQ)                     NaN
# 17                                Fiscal Monitor (FM)                     NaN
# 16                            Fiscal Decentralization                     NaN
# 18                                Fiscal Monitor (FM)                     NaN
# 19                                Fiscal Monitor (FM)                     NaN
# 21  Financial Soundness Indicators Reporting Entit...                     NaN
# 22  Financial Soundness Indicators Reporting Entit...                     NaN
# 23                                             Gender                     NaN
# 20               Financial Soundness Indicators (FSI)                     NaN
# 24                                             Gender                     NaN
# 12                         Financial Development (FD)                     NaN
# 13                            Fiscal Decentralization                     NaN
# 25                      Historical Public Debt (HPDD)                     NaN
# 15                            Fiscal Decentralization                     NaN
# 9                          Financial Development (FD)                     NaN
# 14                            Fiscal Decentralization                     NaN
# 11                         Financial Development (FD)                     NaN
# 1         Coordinated Direct Investment Survey (CDIS)                     NaN
# 2         Coordinated Direct Investment Survey (CDIS)                     NaN
# 8                       Financial Access Survey (FAS)                     NaN
# 3         Coordinated Direct Investment Survey (CDIS)                     NaN
# 0                           Balance of Payments (BOP)                     NaN
# 10                         Financial Development (FD)                     NaN
#
#         mean           vif  overall_mean
# 4   0.221600  4.745166e+06      0.153618
# 5   0.104669  1.159800e+00      0.142143
# 6   0.080969  1.044900e+00      0.117009
# 7   0.137633  2.047621e+03      0.104951
# 17  0.035136  1.075500e+00      0.036727
# 16  0.058614  1.560500e+00      0.031313
# 18  0.036360  1.062100e+00      0.030399
# 19  0.015309  1.075500e+00      0.029131
# 21  0.039217  3.669233e+09      0.028819
# 22  0.017480  1.237752e+09      0.020762
# 23  0.022409  1.163700e+00      0.018577
# 20  0.024862  6.763741e+09      0.017738
# 24  0.017185  1.019600e+00      0.015023
# 12  0.016086  1.046600e+00      0.010640
# 13  0.004433  1.010600e+00      0.009056
# 25  0.004513  1.045100e+00      0.007029
# 15  0.003110  2.750100e+00      0.006809
# 9   0.005455  2.286400e+00      0.006563
# 14  0.005962  1.008100e+00      0.006391
# 11  0.011960  1.167800e+00      0.006077
# 1   0.005050  6.978410e+07      0.006062
# 2   0.006025  7.733078e+07      0.005991
# 8   0.004800  1.026327e+09      0.005573
# 3   0.006122  2.224804e+06      0.005436
# 0   0.004160  5.128073e+07      0.005147
# 10  0.001800  1.192900e+00      0.005045
# Index(['model', 'filename', 'iteration', 'column', 'column_descr',
#        'avg_column_significance', 'mean', 'vif', 'overall_mean'],
#       dtype='object')
#                     model                filename iteration  \
# 10  DecisionTreeRegressor                     FDI         4
# 15  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 0   DecisionTreeRegressor                  BOPAGG         4
# 13  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 25  DecisionTreeRegressor                    HPDD         4
# 8   DecisionTreeRegressor                     FAS         4
# 1   DecisionTreeRegressor                    CDIS         4
# 9   DecisionTreeRegressor                     FDI         4
# 14  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 2   DecisionTreeRegressor                    CDIS         4
# 3   DecisionTreeRegressor                    CDIS         4
# 11  DecisionTreeRegressor                     FDI         4
# 19  DecisionTreeRegressor                      FM         4
# 12  DecisionTreeRegressor                     FDI         4
# 24  DecisionTreeRegressor                  GENDER         4
# 22  DecisionTreeRegressor                   FSIRE         4
# 23  DecisionTreeRegressor                  GENDER         4
# 20  DecisionTreeRegressor                     FSI         4
# 17  DecisionTreeRegressor                      FM         4
# 18  DecisionTreeRegressor                      FM         4
# 21  DecisionTreeRegressor                   FSIRE         4
# 16  DecisionTreeRegressor  FISCALDECENTRALIZATION         4
# 6   DecisionTreeRegressor                      ED         4
# 5   DecisionTreeRegressor                      ED         4
# 7   DecisionTreeRegressor                      EQ         4
# 4   DecisionTreeRegressor                    CDIS         4
#
#                                 column  \
# 10                     FDI_component_1
# 15  FISCALDECENTRALIZATION_component_2
# 0                   BOPAGG_component_0
# 13  FISCALDECENTRALIZATION_component_0
# 25                    HPDD_component_0
# 8                      FAS_component_0
# 1                     CDIS_component_0
# 9                      FDI_component_0
# 14  FISCALDECENTRALIZATION_component_1
# 2                     CDIS_component_1
# 3                     CDIS_component_2
# 11                     FDI_component_2
# 19                      FM_component_2
# 12                     FDI_component_3
# 24                  GENDER_component_1
# 22                   FSIRE_component_1
# 23                  GENDER_component_0
# 20                     FSI_component_0
# 17                      FM_component_0
# 18                      FM_component_1
# 21                   FSIRE_component_0
# 16  FISCALDECENTRALIZATION_component_3
# 6                       ED_component_1
# 5                       ED_component_0
# 7                       EQ_component_0
# 4                     CDIS_component_3
#
#                                          column_descr avg_column_significance  \
# 10                         Financial Development (FD)                     NaN
# 15                            Fiscal Decentralization                     NaN
# 0                           Balance of Payments (BOP)                     NaN
# 13                            Fiscal Decentralization                     NaN
# 25                      Historical Public Debt (HPDD)                     NaN
# 8                       Financial Access Survey (FAS)                     NaN
# 1         Coordinated Direct Investment Survey (CDIS)                     NaN
# 9                          Financial Development (FD)                     NaN
# 14                            Fiscal Decentralization                     NaN
# 2         Coordinated Direct Investment Survey (CDIS)                     NaN
# 3         Coordinated Direct Investment Survey (CDIS)                     NaN
# 11                         Financial Development (FD)                     NaN
# 19                                Fiscal Monitor (FM)                     NaN
# 12                         Financial Development (FD)                     NaN
# 24                                             Gender                     NaN
# 22  Financial Soundness Indicators Reporting Entit...                     NaN
# 23                                             Gender                     NaN
# 20               Financial Soundness Indicators (FSI)                     NaN
# 17                                Fiscal Monitor (FM)                     NaN
# 18                                Fiscal Monitor (FM)                     NaN
# 21  Financial Soundness Indicators Reporting Entit...                     NaN
# 16                            Fiscal Decentralization                     NaN
# 6                         Export Diversification (ED)                     NaN
# 5                         Export Diversification (ED)                     NaN
# 7                                 Export Quality (EQ)                     NaN
# 4         Coordinated Direct Investment Survey (CDIS)                     NaN
#
#         mean           vif  overall_mean
# 10  0.001800  1.192900e+00      0.005045
# 15  0.003110  2.750100e+00      0.006809
# 0   0.004160  5.128073e+07      0.005147
# 13  0.004433  1.010600e+00      0.009056
# 25  0.004513  1.045100e+00      0.007029
# 8   0.004800  1.026327e+09      0.005573
# 1   0.005050  6.978410e+07      0.006062
# 9   0.005455  2.286400e+00      0.006563
# 14  0.005962  1.008100e+00      0.006391
# 2   0.006025  7.733078e+07      0.005991
# 3   0.006122  2.224804e+06      0.005436
# 11  0.011960  1.167800e+00      0.006077
# 19  0.015309  1.075500e+00      0.029131
# 12  0.016086  1.046600e+00      0.010640
# 24  0.017185  1.019600e+00      0.015023
# 22  0.017480  1.237752e+09      0.020762
# 23  0.022409  1.163700e+00      0.018577
# 20  0.024862  6.763741e+09      0.017738
# 17  0.035136  1.075500e+00      0.036727
# 18  0.036360  1.062100e+00      0.030399
# 21  0.039217  3.669233e+09      0.028819
# 16  0.058614  1.560500e+00      0.031313
# 6   0.080969  1.044900e+00      0.117009
# 5   0.104669  1.159800e+00      0.142143
# 7   0.137633  2.047621e+03      0.104951
# 4   0.221600  4.745166e+06      0.153618
# Index(['model', 'filename', 'iteration', 'column', 'column_descr',
#        'avg_column_significance', 'mean', 'vif', 'overall_mean'],
#       dtype='object')

# %%
alt.vconcat(column_chart_dict[1], column_chart_dict[2], column_chart_dict[3]
            , column_chart_dict[4])#.show()
# Out:
# alt.VConcatChart(...)
